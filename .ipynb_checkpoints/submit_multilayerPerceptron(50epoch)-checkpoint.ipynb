# %% [markdown]
# ## 파일 불러오기
# 학습 데이터, 테스트 데이터 로딩

# %%
import pandas as pd
import numpy as np
np.set_printoptions(threshold=np.inf) # print all numpy values
from sklearn.preprocessing import LabelEncoder, LabelBinarizer, OneHotEncoder, MultiLabelBinarizer

# %%
categorical = ['주야', '요일', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', 
            '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
numerical = ['사상자수', '사망자수', '중상자수', '경상자수','부상신고자수']

x_train_num = pd.read_csv('./교통사망사고정보/Kor_Train_교통사망사고정보(12.1~17.6).csv',encoding='cp949', usecols=numerical)

x_train_cat = pd.read_csv('./교통사망사고정보/Kor_Train_교통사망사고정보(12.1~17.6).csv',encoding='cp949', usecols=categorical)

# %%
x_test_num = pd.read_csv('./test_kor.csv',encoding='cp949', usecols=numerical)

x_test_cat = pd.read_csv('./test_kor.csv',encoding='cp949', usecols=categorical)

# %% [markdown]
# ## One Hot Encdoing

# %%
all_data = pd.concat((x_test_cat.dropna(), x_train_cat))
# for col in all_data.select_dtypes(include=[np.object]).columns:
#     print(col, all_data[col].unique())

# %%
for column in all_data.select_dtypes(include=[np.object]).columns:
    x_train_cat[column] = x_train_cat[column].astype('category', categories = all_data[column].unique())
    x_test_cat[column] = x_test_cat[column].astype('category', categories = all_data[column].unique())
# Out:
# /home/iron/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#
# /home/iron/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x_train_cat = pd.get_dummies(data=x_train_cat)
x_test_cat = pd.get_dummies(data=x_test_cat)

# %%
# One Encoding Shape 확인
print(x_train_cat.shape)
print(x_test_cat.shape)
# Out:
# (25037, 328)
# (50, 328)

# %% [markdown]
# # Deep Learning

# %%
import keras
from keras.layers import Dense, Input, LSTM, concatenate, Dropout, Conv2D, MaxPool2D, Embedding, Reshape, Conv1D
from keras.models import Sequential, Model
from keras.utils import np_utils
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from keras import metrics
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
# Train Data Shape
print(x_train_cat.shape)
print(x_train_num.shape)
# Test Data Shape
print(x_test_cat.shape)
print(x_test_num.shape)
# Out:
# (25037, 328)
# (25037, 5)
# (50, 328)
# (50, 5)

# %%
# Numeric cases
Case1 = ['사망자수','사상자수','경상자수']
Case2 = ['사상자수', '중상자수', '부상신고자수']
Case3 = ['사상자수', '중상자수', '경상자수' ]
Case4 = ['사망자수', '사상자수', '중상자수' ]

# Categorical cases
Case5 = ['사고유형_대분류', '사고유형_중분류', '법규위반']
Case6 = ['도로형태_대분류', '도로형태', '당사자종별_1당_대분류']
Case7 = ['도로형태_대분류', '도로형태', '당사자종별_2당_대분류']
Case8 = ['도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
Case11 = ['발생지시도', '발생지시군구']
Case12 = ['요일', '사고유형_대분류', '사고유형_중분류']
Case13 = ['요일', '사고유형_중분류', '법규위반', '도로형태_대분류']

# Mixed cases
Case9 = ['사망자수', '사상자수', '발생지시군구']
Case10 = ['중상자수', '경상자수', '발생지시군구']
Case14 = ['사망자수', '사상자수', '주야', '당사자종별_1당_대분류']
Case15 = ['사상자수', '중상자수', '주야', '도로형태']

Cases = [Case1, Case2, Case3, Case4, Case5, Case6, Case7, Case8, Case9, Case10,
         Case11, Case12, Case13, Case14, Case15]

# %%
# case ranges

case1_range = [0, 1]
case2_range = [2, 3]
case3_range = [4, 6]
case4_range = [7, 9]
case5_range = [10, 19]
case6_range = [20, 22]
case7_range = [23, 25]
case8_range = [26, 29]
case9_range = [30, 31]
case10_range = [32, 34]
case11_range = [35, 39]
case12_range = [40, 41]
case13_range = [42, 44]
case14_range = [45, 46]
case15_range = [47, 49]

test_ranges = [case1_range, case2_range, case3_range, case4_range, case5_range, case6_range,
             case7_range, case8_range, case9_range, case10_range, case11_range, case12_range,
             case13_range, case14_range, case15_range]

# %%
# train, set result in new array
for (idx, case), range_x in zip(enumerate(Cases), test_ranges):
    print(idx+1, case, range_x)
# Out:
# 1 ['사망자수', '사상자수', '경상자수'] [0, 1]
# 2 ['사상자수', '중상자수', '부상신고자수'] [2, 3]
# 3 ['사상자수', '중상자수', '경상자수'] [4, 6]
# 4 ['사망자수', '사상자수', '중상자수'] [7, 9]
# 5 ['사고유형_대분류', '사고유형_중분류', '법규위반'] [10, 19]
# 6 ['도로형태_대분류', '도로형태', '당사자종별_1당_대분류'] [20, 22]
# 7 ['도로형태_대분류', '도로형태', '당사자종별_2당_대분류'] [23, 25]
# 8 ['도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류'] [26, 29]
# 9 ['사망자수', '사상자수', '발생지시군구'] [30, 31]
# 10 ['중상자수', '경상자수', '발생지시군구'] [32, 34]
# 11 ['발생지시도', '발생지시군구'] [35, 39]
# 12 ['요일', '사고유형_대분류', '사고유형_중분류'] [40, 41]
# 13 ['요일', '사고유형_중분류', '법규위반', '도로형태_대분류'] [42, 44]
# 14 ['사망자수', '사상자수', '주야', '당사자종별_1당_대분류'] [45, 46]
# 15 ['사상자수', '중상자수', '주야', '도로형태'] [47, 49]

# %%
def save_result():
    '''
    test file에 있는 값을 result file에 저장
    '''
    test_file = pd.read_csv('./test_kor_1.csv', encoding='cp949', names= [chr(y) for y in range(ord('A'),ord('P')+1)])
    result_file = pd.read_csv('./result_kor.csv', encoding='cp949')
    
    cols = result_file['열'].values
    rows = result_file['행'].values
    vals = result_file['값'].astype('str').values
    
    rows-=1
    
    for i, (row, col) in enumerate(zip(rows, cols)):      
        vals[i] = test_file[col][row]

    rows += 1

    with open('./result_kor1.csv', 'wb') as f:
        for i in result_file.index:
            np.savetxt(f,  np.c_[rows,cols,vals],  delimiter=",", fmt='%s', encoding='cp949', header='행,열,값', comments='')
    print('Save Success')

# %%
# 수치형 데이터 Case 함수

def numeric_case(case, start, end):
    
    K.clear_session()
    case_copy=case.copy()
    
    # Case 확인
    print("Case:", case)
    
    # Train Data
    X = x_train_num.drop(columns=case)
    X = pd.concat([X, x_train_cat], axis=1).values
    
    # Test Data
    X_test = x_test_num.drop(columns=case)
    X_test = pd.concat([X_test, x_test_cat],axis=1).values
    
    # Label Data
    if '사상자수' in case:       
        case_copy.remove('사상자수')
        print('사상자제거:', case_copy) 
    Y = x_train_num[case_copy].values
    
    # Model define
    num_input = Input(shape=(len(X[0]),), name='num_input')
    x = Dense((int(len(X[0] + len(Y[0])) * 2 /3)), activation='relu')(num_input)
    x = Dropout(0.3)(x)
    x = Dense((int(len(X[0] + len(Y[0])) * 2 /3)), activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense((int(len(X[0] + len(Y[0])) * 2 /3)), activation='relu')(x)
    x = Dropout(0.3)(x)
    num_output = Dense(len(Y[0]), name='num_output')(x)

    model = Model(inputs=num_input, outputs=num_output)

    model.compile(optimizer='adam',
                  loss='mse',
                  metrics=['accuracy'])

    learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', patience=25, verbose=1, factor=0.5, min_lr=0.00000001)

    callbacks = [
        learning_rate_reduction, # learning_rate를 점차 감소시킴으로서 최적값에 접근하는 방식
        EarlyStopping('val_loss', patience=15)# val_loss이 최적값에서 멀어지는 순간 epoch가 남아도 학습 중지
    ]
    
    history = model.fit(X, Y, epochs=50, batch_size=128, callbacks=callbacks, validation_split=0.2 )
    
    
    # make a prediction
    Y_test = model.predict(X_test[start:end+1])
    
    del model
    
    return Y_test

# %%
# 범주형 데이터 Case 함수

def categorical_case(case, start, end):
    
    K.clear_session()
    
    # Case 확인
    print("Case:", case)
    
    col_name = [] # ex. '사고유형_대분류_차대차', '사고유형_대분류_차대사람', '사고유형_대분류_차량단독'
    label_name = [] #  ex. '차대차', '차대사람', '차량단독
    
    # One Hot Encoding 후 Columns 이름과 Columns에 들어 있는 값 
    for col in case:
        label_name.extend(all_data[col].unique()) 
        for name in all_data[col].unique():
            col_name.append(col+'_'+name)

    # Train Data 
    X = x_train_cat.drop(columns=col_name)
    X = pd.concat([X, x_train_num], axis=1).values

    # Test Data
    X_test = x_test_cat.drop(columns=col_name)
    X_test = pd.concat([X_test, x_test_num],axis=1).values
    
    # Label Data
    Y = x_train_cat[col_name].values
    
    # Model define
    cat_input = Input(shape=(len(X[0]),), name='cat_input')
    x = Dense(512, activation='relu')(cat_input)
    x = Dropout(0.3)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x)
    cat_output = Dense(len(Y[0]), activation='sigmoid', name='cat_output')(x)

    model = Model(inputs=cat_input, outputs=cat_output)

    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', patience=25, verbose=1, factor=0.5, min_lr=0.00000001)

    callbacks = [
        learning_rate_reduction, # learning_rate를 점차 감소시킴으로서 최적값에 접근하는 방식
        EarlyStopping('val_loss', patience=15), # val_loss이 최적값에서 멀어지는 순간 epoch가 남아도 학습 중지
        ]

    history = model.fit(X, Y, epochs=50, batch_size=128, callbacks=callbacks,validation_split=0.2 )
    
    # make a prediction
    Y_test = model.predict(X_test[start:end+1])
    

    '''
    예시 출력:
        사고유형_대분류 : 차량단독
        사고유형_중분류 : 공작물충돌
        법규위반 : 안전운전 의무 불이행
    '''
    result = []
    for cat in Y_test: 
        x_list = list(cat)
        label_name_x = label_name.copy()
        temp = []
        for col in case:
#             print(col, ':', label_name_x[x_list.index(max(x_list[0:len(all_data[col].unique())]))] )
            temp.append(label_name_x[x_list.index(max(x_list[0:len(all_data[col].unique())]))])
            del x_list[:len(all_data[col].unique())]
            del label_name_x[:len(all_data[col].unique())]
        result.append(temp)
        
        
    del model
    
    return np.array(result)

# %%
# 믹스형 데이터 Case 함수

def mix_case(case, n, start, end):
    '''
    case: Case에 해당되는 컬럼이 담긴 배열
    n: 범주형 데이터 수
    start: 해당 Case 테스트의 시작 인덱스
    end: 해당 Case 테스트의 마지막 인덱스
    '''
    
    case_copy=case.copy()
    
    # categorical
    col_name = []
    label_name = []
    cat_name = case_copy[-n:]
    
    for col in case_copy[-n:]:
        label_name.extend(all_data[col].unique()) 
        for name in all_data[col].unique():
            col_name.append(col+'_'+name)
    
    Y_cat = x_train_cat[col_name].values
    X1 = x_train_cat.drop(columns=col_name)
    X_test1 = x_test_cat.drop(columns=col_name)
    
    # categorical columns 삭제
    del case_copy[-n:]
    
    # numerical
    X2 = x_train_num.drop(columns=case_copy)
    X_test2 = x_test_num.drop(columns=case_copy)
    
    if '사상자수' in case: 
        case_copy.remove('사상자수')
    Y_num = x_train_num[case_copy].values
    
    X = pd.concat([X1, X2], axis=1).values
    X_test = pd.concat([X_test1, X_test2],axis=1).values
    
    # Model define
    cat_input = Input(shape=(len(X[0]),), name='cat_input')
    x = Dense(512, activation='relu')(cat_input)
    x = Dropout(0.3)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    
    if n == 1:
        cat_output = Dense(len(Y_cat[0]), activation='softmax', name='cat_output')(x)
    elif n == 2:
        cat_output = Dense(len(Y_cat[0]), activation='sigmoid', name='cat_output')(x)
        
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    num_output = Dense(len(Y_num[0]), name='num_output')(x)

    model = Model(inputs=cat_input, outputs=[cat_output, num_output])

    if n==1:
        model.compile(optimizer='adam',
                      loss={'cat_output': 'categorical_crossentropy', 'num_output': 'mse'},
                      metrics=['accuracy'])
    elif n==2:
        model.compile(optimizer='adam',
                      loss={'cat_output': 'binary_crossentropy', 'num_output': 'mse'},
                      metrics=['accuracy'])
    
    
    learning_rate_reduction = ReduceLROnPlateau(monitor='cat_output_acc', 
                                            patience=25, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00000001)

    callbacks = [
        learning_rate_reduction, # learning_rate를 점차 감소시킴으로서 최적값에 접근하는 방식
        EarlyStopping('val_loss', patience=20), # val_loss이 최적값에서 멀어지는 순간 epoch가 남아도 학습 중지
    ]

    history = model.fit(X, {'cat_output':Y_cat, 'num_output':Y_num}, epochs=50, batch_size=128, callbacks=callbacks,validation_split=0.2 )
    
    
    # make a prediction
    Y_test = model.predict(X_test[start:end+1])    
    
    result = []
    for cat, num in zip(Y_test[0], Y_test[1]):
        x_list = list(cat)
        label_name_x = label_name.copy()
        temp = []
        for col in cat_name:
            temp.append(label_name_x[x_list.index(max(x_list[0:len(all_data[col].unique())]))])
            
            # 출력한 Column과 데이터 삭제
            del x_list[:len(all_data[col].unique())]
            del label_name_x[:len(all_data[col].unique())]
        temp.extend(num)
        result.append(temp)
        
    
    return np.array(result)

# %%
# set result array to each cases
def setResult(arr, predict, case):
    result_arr = arr
    
    if case == [int(x) for x in range(0, 2)]:
        for row in range(len(predict)):
            result_arr[row, 2] = predict[row, 0] # 사망자수
            result_arr[row, 5] = predict[row, 1] # 사상자수            
            result_arr[row, 3] = result_arr[row, 2] + result_arr[row, 4:7].sum() # 사상자수 = 사망자수 + (중상+경상+부상신고자수)
            
    elif case == [int(x) for x in range(2, 4)]:
        for row in range(len(predict)):
            result_arr[row, 4] = predict[row, 0]
            result_arr[row, 6] = predict[row, 1]
            result_arr[row, 3] = result_arr[row, 2] + result_arr[row, 4:7].sum()
            
    elif case == [int(x) for x in range(4, 7)]:
        for row in range(len(predict)):
            result_arr[row, 4] = predict[row, 0]
            result_arr[row, 5] = predict[row, 1]
            result_arr[row, 3] = result_arr[row, 2] + result_arr[row, 4:7].sum()
            
    elif case == [int(x) for x in range(7, 10)]:
        for row in range(len(predict)):
            result_arr[row, 2] = predict[row, 0]
            result_arr[row, 4] = predict[row, 1]
            result_arr[row, 3] = result_arr[row, 2] + result_arr[row, 4:7].sum()
            
    elif case == [int(x) for x in range(10,20)]:
        for row in range(len(predict)):
            result_arr[row, 9] = predict[row, 0] 
            result_arr[row, 10] = predict[row, 1] 
            result_arr[row, 11] = predict[row, 2] 
            print(result_arr[row, 11], predict[row, 2])
            
    elif case == [int(x) for x in range(20,23)]:
        for row in range(len(predict)):
            result_arr[row, 12] = predict[row, 0] 
            result_arr[row, 13] = predict[row, 1] 
            result_arr[row, 14] = predict[row, 2] 
            
    elif case == [int(x) for x in range(23,26)]:
        for row in range(len(predict)):
            result_arr[row, 12] = predict[row, 0] 
            result_arr[row, 13] = predict[row, 1] 
            result_arr[row, 15] = predict[row, 2] 
    
    elif case == [int(x) for x in range(26,30)]:
        for row in range(len(predict)):
            result_arr[row, 12] = predict[row, 0] 
            result_arr[row, 13] = predict[row, 1] 
            result_arr[row, 14] = predict[row, 2] 
            result_arr[row, 15] = predict[row, 3] 
    
    elif case == [int(x) for x in range(35,40)]:
        for row in range(len(predict)):
            result_arr[row, 7] = predict[row, 0] 
            result_arr[row, 8] = predict[row, 1] 
        
    elif case == [int(x) for x in range(40,42)]:
        for row in range(len(predict)):
            result_arr[row, 1] = predict[row, 0] 
            result_arr[row, 9] = predict[row, 1] 
            result_arr[row, 10] = predict[row, 2] 
        
    elif case == [int(x) for x in range(42,45)]:
        for row in range(len(predict)):
            result_arr[row, 1] = predict[row, 0] 
            result_arr[row, 10] = predict[row, 1] 
            result_arr[row, 11] = predict[row, 2] 
            result_arr[row, 12] = predict[row, 3] 
    
    elif case == [int(x) for x in range(30,32)]:
        for row in range(len(predict)):
            result_arr[row, 2] = float(predict[row, 1])
            result_arr[row, 3] = result_arr[row, 2] + result_arr[row, 4:7].sum()
            result_arr[row, 8] = predict[row, 0]
            
    elif case == [int(x) for x in range(32,35)]:
        for row in range(len(predict)):
            result_arr[row, 4] = predict[row, 1]
            result_arr[row, 5] = predict[row, 2]
            result_arr[row, 8] = predict[row, 0]
            
    elif case == [int(x) for x in range(45,47)]:
        for row in range(len(predict)):
            result_arr[row, 0] = predict[row, 0]
            result_arr[row, 2] = float(predict[row, 2])
            result_arr[row, 14] = predict[row, 1]
            result_arr[row, 3] = result_arr[row, 2] + result_arr[row, 4:7].sum()
            
    elif case == [int(x) for x in range(47,50)]:
        for row in range(len(predict)):
            result_arr[row, 0] = predict[row, 0]
            result_arr[row, 4] = float(predict[row, 2])
            result_arr[row, 13] = predict[row, 1]
            result_arr[row, 3] = result_arr[row, 2] + result_arr[row, 4:7].sum()
    
    print(result_arr)
    return result_arr

# %%
x_test = pd.read_csv('./test_kor.csv',encoding='cp949')

# setResult(each case array, predict array, start to end in each case):

# %%
test_arr = np.array([x_test.columns.values])
print(test_arr)
# Out:
# [['주야' '요일' '사망자수' '사상자수' '중상자수' '경상자수' '부상신고자수' '발생지시도' '발생지시군구'
#   '사고유형_대분류' '사고유형_중분류' '법규위반' '도로형태_대분류' '도로형태' '당사자종별_1당_대분류'
#   '당사자종별_2당_대분류']]

# %%
# train, set result in new array
for (idx, case), case_range in zip(enumerate(Cases), test_ranges):
    # for matching case number +1 to idx
    print()
    # numeric case
    if (idx+1) <= 4:      
#         print(idx+1, case, case_range)
        Case_prediction = numeric_case(case, case_range[0], case_range[1])
        answer = setResult(x_test.loc[case_range[0]:case_range[1]].values, Case_prediction, [int(x) for x in range(case_range[0], case_range[1]+1)])
        test_arr = np.append(test_arr, answer, axis=0)
        
    # categorical case
    elif ((idx+1) >= 5 and (idx+1) <= 8) or ((idx+1) >= 11 and (idx+1) <= 13):
#         print(idx+1, case, case_range)
        Case_prediction = categorical_case(case, case_range[0], case_range[1])
        answer = setResult(x_test.loc[case_range[0]:case_range[1]].values, Case_prediction, [int(x) for x in range(case_range[0], case_range[1]+1)])
        test_arr = np.append(test_arr, answer, axis=0)

    # mixed case
    elif (idx+1) == 9 or (idx+1) == 10 or (idx+1) >= 14:
#         print(idx+1, case, case_range)
        
        if (idx+1) == 9 or (idx+1) == 10:
            num_categories = 1  # number of categories for each case
            
        if (idx+1) == 14 or (idx+1) == 15:
            num_categories = 2
            
        Case_prediction = mix_case(case, num_categories, case_range[0], case_range[1])
        answer = setResult(x_test.loc[case_range[0]:case_range[1]].values, Case_prediction, [int(x) for x in range(case_range[0], case_range[1]+1)])
        test_arr = np.append(test_arr, answer, axis=0)
# Out:
# 1 ['사망자수', '사상자수', '경상자수'] [0, 1]
# Case: ['사망자수', '사상자수', '경상자수']
# 사상자제거: ['사망자수', '경상자수']
# Train on 20029 samples, validate on 5008 samples
# Epoch 1/50
# 20029/20029 [==============================] - 1s 49us/step - loss: 0.6259 - acc: 0.9412 - val_loss: 0.5321 - val_acc: 0.9455
# Epoch 2/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.5765 - acc: 0.9480 - val_loss: 0.5298 - val_acc: 0.9213
# Epoch 3/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.5272 - acc: 0.9433 - val_loss: 0.5300 - val_acc: 0.9513
# Epoch 4/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.5181 - acc: 0.9474 - val_loss: 0.5332 - val_acc: 0.9413
# Epoch 5/50
# 20029/20029 [==============================] - 0s 24us/step - loss: 0.6193 - acc: 0.9443 - val_loss: 0.5090 - val_acc: 0.9307
# Epoch 6/50
# 20029/20029 [==============================] - 0s 24us/step - loss: 0.4897 - acc: 0.9497 - val_loss: 0.5406 - val_acc: 0.9465
# Epoch 7/50
# 20029/20029 [==============================] - 0s 24us/step - loss: 0.4272 - acc: 0.9501 - val_loss: 0.5578 - val_acc: 0.9433
# Epoch 8/50
# 20029/20029 [==============================] - 0s 24us/step - loss: 0.3908 - acc: 0.9558 - val_loss: 0.5413 - val_acc: 0.9445
# Epoch 9/50
# 20029/20029 [==============================] - 0s 24us/step - loss: 0.3192 - acc: 0.9549 - val_loss: 0.6115 - val_acc: 0.9447
# Epoch 10/50
# 20029/20029 [==============================] - 0s 24us/step - loss: 0.3175 - acc: 0.9553 - val_loss: 0.5866 - val_acc: 0.9479
# Epoch 11/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.2567 - acc: 0.9571 - val_loss: 0.6027 - val_acc: 0.9491
# Epoch 12/50
# 20029/20029 [==============================] - 0s 24us/step - loss: 0.2275 - acc: 0.9591 - val_loss: 0.6021 - val_acc: 0.9447
# Epoch 13/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.2577 - acc: 0.9595 - val_loss: 0.6176 - val_acc: 0.9499
# Epoch 14/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.2151 - acc: 0.9597 - val_loss: 0.6447 - val_acc: 0.9485
# Epoch 15/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.2108 - acc: 0.9609 - val_loss: 0.6352 - val_acc: 0.9479
# Epoch 16/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.2056 - acc: 0.9594 - val_loss: 0.6137 - val_acc: 0.9475
# Epoch 17/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.2132 - acc: 0.9613 - val_loss: 0.6325 - val_acc: 0.9461
# Epoch 18/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.2109 - acc: 0.9624 - val_loss: 0.6269 - val_acc: 0.9421
# Epoch 19/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.1991 - acc: 0.9650 - val_loss: 0.6209 - val_acc: 0.9391
# Epoch 20/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.2223 - acc: 0.9621 - val_loss: 0.5889 - val_acc: 0.9459
# [['야간' '금' 1.0739396 1.7806155681610107 0.0 0.706676 0.0 '경기' '화성시' '차대차'
#   '측면충돌' '중앙선 침범' '단일로' '기타단일로' '승용차' '승합차']
#  ['야간' '금' 0.9898085 1.0485250875353813 0.0 0.058716588 0.0 '전남' '영암군'
#   '차대사람' '차도통행중' '과속' '단일로' '기타단일로' '승용차' '보행자']]
#
# 2 ['사상자수', '중상자수', '부상신고자수'] [2, 3]
# Case: ['사상자수', '중상자수', '부상신고자수']
# 사상자제거: ['중상자수', '부상신고자수']
# Train on 20029 samples, validate on 5008 samples
# Epoch 1/50
# 20029/20029 [==============================] - 1s 29us/step - loss: 0.5211 - acc: 0.8477 - val_loss: 0.9015 - val_acc: 0.8141
# Epoch 2/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.4953 - acc: 0.9080 - val_loss: 0.9204 - val_acc: 0.9900
# Epoch 3/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.4890 - acc: 0.9474 - val_loss: 0.9015 - val_acc: 0.9906
# Epoch 4/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.4903 - acc: 0.9635 - val_loss: 0.8728 - val_acc: 0.9906
# Epoch 5/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.4515 - acc: 0.9691 - val_loss: 0.8739 - val_acc: 0.9906
# Epoch 6/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.4162 - acc: 0.9615 - val_loss: 0.8859 - val_acc: 0.9906
# Epoch 7/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.4133 - acc: 0.9571 - val_loss: 0.8975 - val_acc: 0.9900
# Epoch 8/50
# 20029/20029 [==============================] - 1s 25us/step - loss: 0.3926 - acc: 0.9494 - val_loss: 0.9006 - val_acc: 0.9906
# Epoch 9/50
# 20029/20029 [==============================] - 0s 24us/step - loss: 0.3488 - acc: 0.9619 - val_loss: 0.9173 - val_acc: 0.9904
# Epoch 10/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.3247 - acc: 0.9562 - val_loss: 0.8944 - val_acc: 0.9904
# Epoch 11/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.3111 - acc: 0.9579 - val_loss: 0.9163 - val_acc: 0.9904
# Epoch 12/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.2894 - acc: 0.9615 - val_loss: 0.9067 - val_acc: 0.9902
# Epoch 13/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.2949 - acc: 0.9582 - val_loss: 0.9086 - val_acc: 0.9904
# Epoch 14/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.2642 - acc: 0.9513 - val_loss: 0.9087 - val_acc: 0.9882
# Epoch 15/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.2327 - acc: 0.9530 - val_loss: 0.9392 - val_acc: 0.9856
# Epoch 16/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.2509 - acc: 0.9488 - val_loss: 0.9333 - val_acc: 0.9904
# Epoch 17/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.2101 - acc: 0.9586 - val_loss: 0.9261 - val_acc: 0.9898
# Epoch 18/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.2011 - acc: 0.9429 - val_loss: 0.9189 - val_acc: 0.9904
# Epoch 19/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.2369 - acc: 0.9395 - val_loss: 1.0037 - val_acc: 0.9858
# [['야간' '월' 1.0 1.0424908297136426 0.038185462 0.0 0.0043053674 '전남' '곡성군'
#   '차량단독' '전도전복' '안전운전 의무 불이행' '단일로' '기타단일로' '자전거' '없음']
#  ['야간' '일' 2.0 3.843921422958374 0.7947301 1.0 0.049191296 '대구' '달성군'
#   '차대차' '측면충돌' '중앙선 침범' '단일로' '기타단일로' '승용차' '승합차']]
#
# 3 ['사상자수', '중상자수', '경상자수'] [4, 6]
# Case: ['사상자수', '중상자수', '경상자수']
# 사상자제거: ['중상자수', '경상자수']
# Train on 20029 samples, validate on 5008 samples
# Epoch 1/50
# 20029/20029 [==============================] - 1s 28us/step - loss: 1.0991 - acc: 0.6066 - val_loss: 0.9985 - val_acc: 0.7286
# Epoch 2/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 1.0078 - acc: 0.6035 - val_loss: 0.9929 - val_acc: 0.3554
# Epoch 3/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.9539 - acc: 0.6232 - val_loss: 1.0078 - val_acc: 0.5747
# Epoch 4/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.9021 - acc: 0.6358 - val_loss: 1.0605 - val_acc: 0.7466
# Epoch 5/50
# 20029/20029 [==============================] - 0s 24us/step - loss: 0.8533 - acc: 0.6356 - val_loss: 1.1109 - val_acc: 0.8253
# Epoch 6/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.8006 - acc: 0.6723 - val_loss: 1.0983 - val_acc: 0.8886
# Epoch 7/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.7611 - acc: 0.6885 - val_loss: 1.0974 - val_acc: 0.8590
# Epoch 8/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.6852 - acc: 0.7163 - val_loss: 1.1273 - val_acc: 0.8796
# Epoch 9/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.6430 - acc: 0.7317 - val_loss: 1.1414 - val_acc: 0.8672
# Epoch 10/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.6091 - acc: 0.7033 - val_loss: 1.2257 - val_acc: 0.6320
# Epoch 11/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.5630 - acc: 0.6708 - val_loss: 1.1510 - val_acc: 0.4379
# Epoch 12/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.5376 - acc: 0.6931 - val_loss: 1.1072 - val_acc: 0.8750
# Epoch 13/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.4941 - acc: 0.7200 - val_loss: 1.1865 - val_acc: 0.8942
# Epoch 14/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.4958 - acc: 0.7567 - val_loss: 1.3321 - val_acc: 0.5569
# Epoch 15/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.4488 - acc: 0.7299 - val_loss: 1.2515 - val_acc: 0.8472
# Epoch 16/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.4450 - acc: 0.7521 - val_loss: 1.2437 - val_acc: 0.8053
# Epoch 17/50
# 20029/20029 [==============================] - 0s 23us/step - loss: 0.4294 - acc: 0.7263 - val_loss: 1.2040 - val_acc: 0.4307
# [['주간' '목' 1.0 2.583216428756714 1.0845929 0.4986235 0.0 '전남' '고흥군' '차대차'
#   '정면충돌' '중앙선 침범' '단일로' '기타단일로' '화물차' '화물차']
#  ['주간' '목' 2.0 3.3249988555908203 0.94152194 0.3834769 0.0 '경북' '영천시'
#   '차대차' '추돌' '안전운전 의무 불이행' '단일로' '기타단일로' '화물차' '화물차']
#  ['야간' '수' 1.0 1.6880871653556824 0.36311215 0.324975 0.0 '충남' '아산시'
#   '차대차' '추돌' '안전거리 미확보' '단일로' '기타단일로' '승합차' '화물차']]
#
# 4 ['사망자수', '사상자수', '중상자수'] [7, 9]
# Case: ['사망자수', '사상자수', '중상자수']
# 사상자제거: ['사망자수', '중상자수']
# Train on 20029 samples, validate on 5008 samples
# Epoch 1/50
# 20029/20029 [==============================] - 1s 28us/step - loss: 0.5413 - acc: 0.9250 - val_loss: 0.4972 - val_acc: 0.9241
# Epoch 2/50
# 20029/20029 [==============================] - 1s 35us/step - loss: 0.4776 - acc: 0.9286 - val_loss: 0.5018 - val_acc: 0.9181
# Epoch 3/50
# 20029/20029 [==============================] - 0s 25us/step - loss: 0.4479 - acc: 0.9293 - val_loss: 0.5003 - val_acc: 0.9235
# Epoch 4/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.4429 - acc: 0.9314 - val_loss: 0.4689 - val_acc: 0.9155
# Epoch 5/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.4024 - acc: 0.9330 - val_loss: 0.5163 - val_acc: 0.9261
# Epoch 6/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.4162 - acc: 0.9365 - val_loss: 0.4794 - val_acc: 0.9255
# Epoch 7/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.3952 - acc: 0.9383 - val_loss: 0.4999 - val_acc: 0.9325
# Epoch 8/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.4060 - acc: 0.9359 - val_loss: 0.4776 - val_acc: 0.9195
# Epoch 9/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.3335 - acc: 0.9437 - val_loss: 0.4757 - val_acc: 0.9267
# Epoch 10/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.3078 - acc: 0.9457 - val_loss: 0.4984 - val_acc: 0.9293
# Epoch 11/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.3009 - acc: 0.9462 - val_loss: 0.5169 - val_acc: 0.9239
# Epoch 12/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.2845 - acc: 0.9488 - val_loss: 0.5504 - val_acc: 0.9249
# Epoch 13/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.2775 - acc: 0.9490 - val_loss: 0.5094 - val_acc: 0.9353
# Epoch 14/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.2494 - acc: 0.9484 - val_loss: 0.6191 - val_acc: 0.9299
# Epoch 15/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.2303 - acc: 0.9519 - val_loss: 0.5435 - val_acc: 0.9295
# Epoch 16/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.2093 - acc: 0.9549 - val_loss: 0.5251 - val_acc: 0.9293
# Epoch 17/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.2103 - acc: 0.9541 - val_loss: 0.5455 - val_acc: 0.9191
# Epoch 18/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.1810 - acc: 0.9551 - val_loss: 0.5449 - val_acc: 0.9223
# Epoch 19/50
# 20029/20029 [==============================] - 0s 22us/step - loss: 0.1841 - acc: 0.9565 - val_loss: 0.5238 - val_acc: 0.9287
# [['주간' '월' 1.0746013 6.599655568599701 0.5250543 5.0 0.0 '충남' '서천군' '차대차'
#   '추돌' '안전운전 의무 불이행' '단일로' '기타단일로' '승용차' '특수차']
#  ['주간' '일' 2.0433056 38.72815251350403 11.684847 21.0 4.0 '강원' '평창군'
#   '차대차' '측면충돌' '기타(운전자법규위반)' '단일로' '기타단일로' '건설기계' '승합차']
#  ['주간' '수' 1.028527 1.0791440345346928 0.050617013 0.0 0.0 '충북' '음성군'
#   '차대사람' '횡단중' '과속' '교차로' '교차로내' '승용차' '보행자']]
#
# 5 ['사고유형_대분류', '사고유형_중분류', '법규위반'] [10, 19]
# Case: ['사고유형_대분류', '사고유형_중분류', '법규위반']
# Train on 20029 samples, validate on 5008 samples
# Epoch 1/50
# 20029/20029 [==============================] - 1s 42us/step - loss: 0.1418 - acc: 0.9476 - val_loss: 0.0814 - val_acc: 0.9658
# Epoch 2/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0864 - acc: 0.9649 - val_loss: 0.0779 - val_acc: 0.9678
# Epoch 3/50
# 20029/20029 [==============================] - 1s 35us/step - loss: 0.0819 - acc: 0.9664 - val_loss: 0.0772 - val_acc: 0.9685
# Epoch 4/50
# 20029/20029 [==============================] - 1s 33us/step - loss: 0.0797 - acc: 0.9674 - val_loss: 0.0763 - val_acc: 0.9687
# Epoch 5/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0782 - acc: 0.9681 - val_loss: 0.0760 - val_acc: 0.9690
# Epoch 6/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0768 - acc: 0.9686 - val_loss: 0.0765 - val_acc: 0.9686
# Epoch 7/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0755 - acc: 0.9692 - val_loss: 0.0769 - val_acc: 0.9682
# Epoch 8/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0744 - acc: 0.9696 - val_loss: 0.0768 - val_acc: 0.9683
# Epoch 9/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0735 - acc: 0.9702 - val_loss: 0.0774 - val_acc: 0.9680
# Epoch 10/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0720 - acc: 0.9707 - val_loss: 0.0777 - val_acc: 0.9681
# Epoch 11/50
# 20029/20029 [==============================] - 1s 35us/step - loss: 0.0709 - acc: 0.9712 - val_loss: 0.0785 - val_acc: 0.9675
# Epoch 12/50
# 20029/20029 [==============================] - 1s 36us/step - loss: 0.0699 - acc: 0.9717 - val_loss: 0.0784 - val_acc: 0.9677
# Epoch 13/50
# 20029/20029 [==============================] - 1s 35us/step - loss: 0.0682 - acc: 0.9724 - val_loss: 0.0792 - val_acc: 0.9681
# Epoch 14/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0669 - acc: 0.9730 - val_loss: 0.0799 - val_acc: 0.9676
# Epoch 15/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0660 - acc: 0.9733 - val_loss: 0.0810 - val_acc: 0.9673
# Epoch 16/50
# 20029/20029 [==============================] - 1s 35us/step - loss: 0.0649 - acc: 0.9738 - val_loss: 0.0814 - val_acc: 0.9671
# Epoch 17/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0635 - acc: 0.9744 - val_loss: 0.0830 - val_acc: 0.9668
# Epoch 18/50
# 20029/20029 [==============================] - 1s 36us/step - loss: 0.0627 - acc: 0.9748 - val_loss: 0.0834 - val_acc: 0.9666
# Epoch 19/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0615 - acc: 0.9752 - val_loss: 0.0832 - val_acc: 0.9668
# Epoch 20/50
# 20029/20029 [==============================] - 1s 35us/step - loss: 0.0605 - acc: 0.9757 - val_loss: 0.0851 - val_acc: 0.9663
# 신호위반 신호위반
# 안전운전 의무 불이행 안전운전 의무 불이행
# 안전운전 의무 불이행 안전운전 의무 불이행
# 안전운전 의무 불이행 안전운전 의무 불이행
# 중앙선 침범 중앙선 침범
# 안전운전 의무 불이행 안전운전 의무 불이행
# 직진 및 우회전차의 통행방해 직진 및 우회전차의 통행방해
# 안전운전 의무 불이행 안전운전 의무 불이행
# 안전운전 의무 불이행 안전운전 의무 불이행
# 안전운전 의무 불이행 안전운전 의무 불이행
# [['주간' '수' 1.0 2.0 1.0 0.0 0.0 '경남' '의령군' '차대차' '측면직각충돌' '신호위반' '교차로'
#   '교차로내' '이륜차' '화물차']
#  ['야간' '화' 2.0 3.0 1.0 0.0 0.0 '대전' '중구' '차량단독' '전도전복' '안전운전 의무 불이행'
#   '단일로' '기타단일로' '원동기장치자전거' '없음']
#  ['야간' '화' 1.0 1.0 0.0 0.0 0.0 '대구' '북구' '차대차' '추돌' '안전운전 의무 불이행' '단일로'
#   '기타단일로' '승용차' '화물차']
#  ['야간' '화' 1.0 1.0 0.0 0.0 0.0 '울산' '울주군' '차대사람' '기타' '안전운전 의무 불이행' '단일로'
#   '기타단일로' '승용차' '보행자']
#  ['주간' '화' 1.0 5.0 1.0 3.0 0.0 '경기' '수원시' '차대차' '측면직각충돌' '중앙선 침범' '단일로'
#   '교량위' '화물차' '승용차']
#  ['주간' '화' 1.0 1.0 0.0 0.0 0.0 '전북' '완주군' '차대사람' '횡단중' '안전운전 의무 불이행'
#   '교차로' '교차로횡단보도내' '승합차' '보행자']
#  ['주간' '화' 1.0 6.0 3.0 2.0 0.0 '경남' '거창군' '차대차' '측면직각충돌'
#   '직진 및 우회전차의 통행방해' '교차로' '교차로내' '승용차' '승합차']
#  ['야간' '화' 1.0 1.0 0.0 0.0 0.0 '충남' '천안시' '차대사람' '횡단중' '안전운전 의무 불이행'
#   '단일로' '기타단일로' '승용차' '보행자']
#  ['주간' '화' 1.0 11.0 2.0 8.0 0.0 '충남' '서산시' '차대차' '추돌' '안전운전 의무 불이행' '단일로'
#   '기타단일로' '화물차' '승용차']
#  ['주간' '화' 1.0 1.0 0.0 0.0 0.0 '전남' '곡성군' '차대사람' '횡단중' '안전운전 의무 불이행'
#   '교차로' '교차로내' '승합차' '보행자']]
#
# 6 ['도로형태_대분류', '도로형태', '당사자종별_1당_대분류'] [20, 22]
# Case: ['도로형태_대분류', '도로형태', '당사자종별_1당_대분류']
# Train on 20029 samples, validate on 5008 samples
# Epoch 1/50
# 20029/20029 [==============================] - 1s 41us/step - loss: 0.1819 - acc: 0.9290 - val_loss: 0.1393 - val_acc: 0.9466
# Epoch 2/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1411 - acc: 0.9451 - val_loss: 0.1344 - val_acc: 0.9467
# Epoch 3/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1365 - acc: 0.9464 - val_loss: 0.1340 - val_acc: 0.9470
# Epoch 4/50
# 20029/20029 [==============================] - 1s 33us/step - loss: 0.1343 - acc: 0.9469 - val_loss: 0.1335 - val_acc: 0.9476
# Epoch 5/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1316 - acc: 0.9478 - val_loss: 0.1344 - val_acc: 0.9470
# Epoch 6/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1294 - acc: 0.9487 - val_loss: 0.1336 - val_acc: 0.9472
# Epoch 7/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1270 - acc: 0.9495 - val_loss: 0.1351 - val_acc: 0.9462
# Epoch 8/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1253 - acc: 0.9500 - val_loss: 0.1351 - val_acc: 0.9470
# Epoch 9/50
# 20029/20029 [==============================] - 1s 33us/step - loss: 0.1226 - acc: 0.9509 - val_loss: 0.1370 - val_acc: 0.9456
# Epoch 10/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1199 - acc: 0.9520 - val_loss: 0.1385 - val_acc: 0.9460
# Epoch 11/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1180 - acc: 0.9525 - val_loss: 0.1391 - val_acc: 0.9456
# Epoch 12/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1153 - acc: 0.9535 - val_loss: 0.1421 - val_acc: 0.9446
# Epoch 13/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1133 - acc: 0.9543 - val_loss: 0.1481 - val_acc: 0.9430
# Epoch 14/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1112 - acc: 0.9552 - val_loss: 0.1469 - val_acc: 0.9453
# Epoch 15/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1089 - acc: 0.9558 - val_loss: 0.1493 - val_acc: 0.9426
# Epoch 16/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1070 - acc: 0.9567 - val_loss: 0.1540 - val_acc: 0.9430
# Epoch 17/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1047 - acc: 0.9574 - val_loss: 0.1576 - val_acc: 0.9422
# Epoch 18/50
# 20029/20029 [==============================] - 1s 33us/step - loss: 0.1034 - acc: 0.9582 - val_loss: 0.1590 - val_acc: 0.9406
# Epoch 19/50
# 20029/20029 [==============================] - 1s 33us/step - loss: 0.1018 - acc: 0.9586 - val_loss: 0.1563 - val_acc: 0.9425
# [['야간' '토' 1.0 11.0 0.0 0.0 10.0 '경기' '의왕시' '차대차' '추돌' '안전운전 의무 불이행'
#   '단일로' '기타단일로' '승용차' '화물차']
#  ['주간' '화' 1.0 13.0 3.0 9.0 0.0 '경기' '평택시' '차대차' '추돌' '안전운전 의무 불이행' '단일로'
#   '기타단일로' '화물차' '화물차']
#  ['주간' '화' 1.0 1.0 0.0 0.0 0.0 '전남' '광양시' '차대사람' '보도통행중' '안전운전 의무 불이행'
#   '단일로' '기타단일로' '승용차' '보행자']]
#
# 7 ['도로형태_대분류', '도로형태', '당사자종별_2당_대분류'] [23, 25]
# Case: ['도로형태_대분류', '도로형태', '당사자종별_2당_대분류']
# Train on 20029 samples, validate on 5008 samples
# Epoch 1/50
# 20029/20029 [==============================] - 1s 41us/step - loss: 0.1533 - acc: 0.9426 - val_loss: 0.1027 - val_acc: 0.9617
# Epoch 2/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1064 - acc: 0.9600 - val_loss: 0.0997 - val_acc: 0.9620
# Epoch 3/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.1019 - acc: 0.9611 - val_loss: 0.0988 - val_acc: 0.9622
# Epoch 4/50
# 20029/20029 [==============================] - 1s 33us/step - loss: 0.0991 - acc: 0.9618 - val_loss: 0.0983 - val_acc: 0.9625
# Epoch 5/50
# 20029/20029 [==============================] - 1s 33us/step - loss: 0.0970 - acc: 0.9623 - val_loss: 0.0994 - val_acc: 0.9620
# Epoch 6/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0951 - acc: 0.9630 - val_loss: 0.0994 - val_acc: 0.9620
# Epoch 7/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0930 - acc: 0.9637 - val_loss: 0.1005 - val_acc: 0.9616
# Epoch 8/50
# 20029/20029 [==============================] - 1s 38us/step - loss: 0.0914 - acc: 0.9640 - val_loss: 0.1009 - val_acc: 0.9611
# Epoch 9/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0889 - acc: 0.9647 - val_loss: 0.1046 - val_acc: 0.9598
# Epoch 10/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0870 - acc: 0.9656 - val_loss: 0.1049 - val_acc: 0.9605
# Epoch 11/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0849 - acc: 0.9662 - val_loss: 0.1052 - val_acc: 0.9615
# Epoch 12/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0825 - acc: 0.9671 - val_loss: 0.1083 - val_acc: 0.9595
# Epoch 13/50
# 20029/20029 [==============================] - 1s 34us/step - loss: 0.0805 - acc: 0.9678 - val_loss: 0.1106 - val_acc: 0.9600
# Epoch 14/50
# 20029/20029 [==============================] - 1s 38us/step - loss: 0.0789 - acc: 0.9685 - val_loss: 0.1083 - val_acc: 0.9599
# Epoch 15/50
# 20029/20029 [==============================] - 1s 36us/step - loss: 0.0767 - acc: 0.9693 - val_loss: 0.1156 - val_acc: 0.9588
# Epoch 16/50
# 20029/20029 [==============================] - 1s 33us/step - loss: 0.0750 - acc: 0.9699 - val_loss: 0.1146 - val_acc: 0.9571
# Epoch 17/50
# 20029/20029 [==============================] - 1s 33us/step - loss: 0.0732 - acc: 0.9707 - val_loss: 0.1191 - val_acc: 0.9598
# Epoch 18/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.0712 - acc: 0.9714 - val_loss: 0.1226 - val_acc: 0.9553
# Epoch 19/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.0698 - acc: 0.9720 - val_loss: 0.1253 - val_acc: 0.9571
# [['야간' '목' 1.0 2.0 0.0 1.0 0.0 '경기' '평택시' '차대차' '측면충돌' '신호위반' '교차로'
#   '교차로내' '승용차' '승용차']
#  ['야간' '목' 1.0 2.0 0.0 1.0 0.0 '충남' '당진시' '차량단독' '공작물충돌' '안전운전 의무 불이행'
#   '단일로' '기타단일로' '이륜차' '없음']
#  ['야간' '월' 1.0 1.0 0.0 0.0 0.0 '전북' '익산시' '차대사람' '기타' '보행자 보호의무 위반' '단일로'
#   '횡단보도상' '승용차' '보행자']]
#
# 8 ['도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류'] [26, 29]
# Case: ['도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# Train on 20029 samples, validate on 5008 samples
# Epoch 1/50
# 20029/20029 [==============================] - 1s 39us/step - loss: 0.1776 - acc: 0.9317 - val_loss: 0.1224 - val_acc: 0.9528
# Epoch 2/50
# 20029/20029 [==============================] - 1s 31us/step - loss: 0.1268 - acc: 0.9514 - val_loss: 0.1194 - val_acc: 0.9540
# Epoch 3/50
# 20029/20029 [==============================] - 1s 31us/step - loss: 0.1224 - acc: 0.9530 - val_loss: 0.1186 - val_acc: 0.9539
# Epoch 4/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.1196 - acc: 0.9535 - val_loss: 0.1189 - val_acc: 0.9534
# Epoch 5/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.1182 - acc: 0.9539 - val_loss: 0.1179 - val_acc: 0.9540
# Epoch 6/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.1164 - acc: 0.9545 - val_loss: 0.1181 - val_acc: 0.9541
# Epoch 7/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.1152 - acc: 0.9550 - val_loss: 0.1180 - val_acc: 0.9539
# Epoch 8/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.1137 - acc: 0.9555 - val_loss: 0.1186 - val_acc: 0.9539
# Epoch 9/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.1123 - acc: 0.9559 - val_loss: 0.1188 - val_acc: 0.9537
# Epoch 10/50
# 20029/20029 [==============================] - 1s 33us/step - loss: 0.1109 - acc: 0.9564 - val_loss: 0.1200 - val_acc: 0.9535
# Epoch 11/50
# 20029/20029 [==============================] - 1s 33us/step - loss: 0.1093 - acc: 0.9568 - val_loss: 0.1208 - val_acc: 0.9533
# Epoch 12/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.1078 - acc: 0.9573 - val_loss: 0.1213 - val_acc: 0.9532
# Epoch 13/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.1064 - acc: 0.9580 - val_loss: 0.1235 - val_acc: 0.9530
# Epoch 14/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.1053 - acc: 0.9583 - val_loss: 0.1230 - val_acc: 0.9533
# Epoch 15/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.1036 - acc: 0.9586 - val_loss: 0.1285 - val_acc: 0.9501
# Epoch 16/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.1023 - acc: 0.9593 - val_loss: 0.1265 - val_acc: 0.9524
# Epoch 17/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.1015 - acc: 0.9595 - val_loss: 0.1276 - val_acc: 0.9519
# Epoch 18/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.0999 - acc: 0.9600 - val_loss: 0.1293 - val_acc: 0.9521
# Epoch 19/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.0987 - acc: 0.9605 - val_loss: 0.1310 - val_acc: 0.9516
# Epoch 20/50
# 20029/20029 [==============================] - 1s 32us/step - loss: 0.0979 - acc: 0.9609 - val_loss: 0.1308 - val_acc: 0.9515
# [['야간' '월' 1.0 2.0 0.0 1.0 0.0 '경남' '하동군' '차대차' '추돌' '과속' '단일로' '기타단일로'
#   '승용차' '승용차']
#  ['야간' '월' 1.0 2.0 1.0 0.0 0.0 '서울' '동대문구' '차대차' '측면충돌' '안전운전 의무 불이행'
#   '교차로' '교차로내' '이륜차' '승용차']
#  ['야간' '수' 1.0 1.0 0.0 0.0 0.0 '경기' '평택시' '차량단독' '기타' '안전운전 의무 불이행' '단일로'
#   '기타단일로' '승용차' '없음']
#  ['주간' '수' 2.0 5.0 1.0 2.0 0.0 '충남' '홍성군' '차대차' '추돌' '안전운전 의무 불이행' '단일로'
#   '기타단일로' '화물차' '화물차']]
#
# 9 ['사망자수', '사상자수', '발생지시군구'] [30, 31]
# Train on 20029 samples, validate on 5008 samples
# Epoch 1/50
# 20029/20029 [==============================] - 1s 56us/step - loss: 4.9017 - cat_output_loss: 4.7745 - num_output_loss: 0.1272 - cat_output_acc: 0.0480 - num_output_acc: 0.9310 - val_loss: 3.5509 - val_cat_output_loss: 3.3409 - val_num_output_loss: 0.2101 - val_cat_output_acc: 0.1160 - val_num_output_acc: 0.9395
# Epoch 2/50
# 20029/20029 [==============================] - 1s 44us/step - loss: 3.1157 - cat_output_loss: 3.0073 - num_output_loss: 0.1084 - cat_output_acc: 0.1314 - num_output_acc: 0.9471 - val_loss: 2.8625 - val_cat_output_loss: 2.7633 - val_num_output_loss: 0.0992 - val_cat_output_acc: 0.1442 - val_num_output_acc: 0.9625
# Epoch 3/50
# 20029/20029 [==============================] - 1s 43us/step - loss: 2.9017 - cat_output_loss: 2.8055 - num_output_loss: 0.0963 - cat_output_acc: 0.1435 - num_output_acc: 0.9578 - val_loss: 2.8595 - val_cat_output_loss: 2.7288 - val_num_output_loss: 0.1307 - val_cat_output_acc: 0.1488 - val_num_output_acc: 0.9625
# Epoch 4/50
# 20029/20029 [==============================] - 1s 43us/step - loss: 2.8394 - cat_output_loss: 2.7523 - num_output_loss: 0.0871 - cat_output_acc: 0.1505 - num_output_acc: 0.9628 - val_loss: 2.7820 - val_cat_output_loss: 2.7022 - val_num_output_loss: 0.0798 - val_cat_output_acc: 0.1522 - val_num_output_acc: 0.9629
# Epoch 5/50
# 20029/20029 [==============================] - 1s 43us/step - loss: 2.8062 - cat_output_loss: 2.7234 - num_output_loss: 0.0828 - cat_output_acc: 0.1564 - num_output_acc: 0.9643 - val_loss: 2.7820 - val_cat_output_loss: 2.7093 - val_num_output_loss: 0.0727 - val_cat_output_acc: 0.1488 - val_num_output_acc: 0.9629
# Epoch 6/50
# 20029/20029 [==============================] - 1s 44us/step - loss: 2.7795 - cat_output_loss: 2.6998 - num_output_loss: 0.0797 - cat_output_acc: 0.1583 - num_output_acc: 0.9651 - val_loss: 2.7654 - val_cat_output_loss: 2.6899 - val_num_output_loss: 0.0755 - val_cat_output_acc: 0.1488 - val_num_output_acc: 0.9629
# Epoch 7/50
# 20029/20029 [==============================] - 1s 50us/step - loss: 2.7592 - cat_output_loss: 2.6816 - num_output_loss: 0.0776 - cat_output_acc: 0.1649 - num_output_acc: 0.9662 - val_loss: 2.7665 - val_cat_output_loss: 2.6957 - val_num_output_loss: 0.0707 - val_cat_output_acc: 0.1562 - val_num_output_acc: 0.9629
# Epoch 8/50
# 20029/20029 [==============================] - 1s 48us/step - loss: 2.7373 - cat_output_loss: 2.6628 - num_output_loss: 0.0744 - cat_output_acc: 0.1695 - num_output_acc: 0.9668 - val_loss: 2.7679 - val_cat_output_loss: 2.6915 - val_num_output_loss: 0.0764 - val_cat_output_acc: 0.1565 - val_num_output_acc: 0.9629
# Epoch 9/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.7178 - cat_output_loss: 2.6448 - num_output_loss: 0.0730 - cat_output_acc: 0.1747 - num_output_acc: 0.9665 - val_loss: 2.7568 - val_cat_output_loss: 2.6924 - val_num_output_loss: 0.0644 - val_cat_output_acc: 0.1544 - val_num_output_acc: 0.9629
# Epoch 10/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.6998 - cat_output_loss: 2.6284 - num_output_loss: 0.0715 - cat_output_acc: 0.1793 - num_output_acc: 0.9670 - val_loss: 2.7540 - val_cat_output_loss: 2.6878 - val_num_output_loss: 0.0662 - val_cat_output_acc: 0.1657 - val_num_output_acc: 0.9629
# Epoch 11/50
# 20029/20029 [==============================] - 1s 47us/step - loss: 2.6789 - cat_output_loss: 2.6097 - num_output_loss: 0.0692 - cat_output_acc: 0.1900 - num_output_acc: 0.9670 - val_loss: 2.7692 - val_cat_output_loss: 2.6975 - val_num_output_loss: 0.0717 - val_cat_output_acc: 0.1599 - val_num_output_acc: 0.9627
# Epoch 12/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 2.6642 - cat_output_loss: 2.5945 - num_output_loss: 0.0697 - cat_output_acc: 0.1915 - num_output_acc: 0.9672 - val_loss: 2.7679 - val_cat_output_loss: 2.7048 - val_num_output_loss: 0.0631 - val_cat_output_acc: 0.1571 - val_num_output_acc: 0.9629
# Epoch 13/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 2.6460 - cat_output_loss: 2.5777 - num_output_loss: 0.0683 - cat_output_acc: 0.1946 - num_output_acc: 0.9676 - val_loss: 2.7628 - val_cat_output_loss: 2.6985 - val_num_output_loss: 0.0643 - val_cat_output_acc: 0.1562 - val_num_output_acc: 0.9629
# Epoch 14/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 2.6327 - cat_output_loss: 2.5663 - num_output_loss: 0.0664 - cat_output_acc: 0.1971 - num_output_acc: 0.9676 - val_loss: 2.7739 - val_cat_output_loss: 2.7100 - val_num_output_loss: 0.0639 - val_cat_output_acc: 0.1601 - val_num_output_acc: 0.9629
# Epoch 15/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.6067 - cat_output_loss: 2.5390 - num_output_loss: 0.0677 - cat_output_acc: 0.2075 - num_output_acc: 0.9674 - val_loss: 2.7942 - val_cat_output_loss: 2.7286 - val_num_output_loss: 0.0656 - val_cat_output_acc: 0.1577 - val_num_output_acc: 0.9629
# Epoch 16/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.5924 - cat_output_loss: 2.5263 - num_output_loss: 0.0661 - cat_output_acc: 0.2085 - num_output_acc: 0.9675 - val_loss: 2.7751 - val_cat_output_loss: 2.7124 - val_num_output_loss: 0.0627 - val_cat_output_acc: 0.1575 - val_num_output_acc: 0.9629
# Epoch 17/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 2.5686 - cat_output_loss: 2.5029 - num_output_loss: 0.0656 - cat_output_acc: 0.2149 - num_output_acc: 0.9672 - val_loss: 2.8059 - val_cat_output_loss: 2.7333 - val_num_output_loss: 0.0726 - val_cat_output_acc: 0.1460 - val_num_output_acc: 0.9629
# Epoch 18/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.5525 - cat_output_loss: 2.4874 - num_output_loss: 0.0651 - cat_output_acc: 0.2212 - num_output_acc: 0.9672 - val_loss: 2.7942 - val_cat_output_loss: 2.7319 - val_num_output_loss: 0.0623 - val_cat_output_acc: 0.1430 - val_num_output_acc: 0.9629
# Epoch 19/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.5337 - cat_output_loss: 2.4683 - num_output_loss: 0.0654 - cat_output_acc: 0.2255 - num_output_acc: 0.9672 - val_loss: 2.8219 - val_cat_output_loss: 2.7585 - val_num_output_loss: 0.0634 - val_cat_output_acc: 0.1480 - val_num_output_acc: 0.9629
# Epoch 20/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 2.5128 - cat_output_loss: 2.4480 - num_output_loss: 0.0648 - cat_output_acc: 0.2336 - num_output_acc: 0.9673 - val_loss: 2.8227 - val_cat_output_loss: 2.7584 - val_num_output_loss: 0.0642 - val_cat_output_acc: 0.1532 - val_num_output_acc: 0.9629
# Epoch 21/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.4871 - cat_output_loss: 2.4226 - num_output_loss: 0.0645 - cat_output_acc: 0.2447 - num_output_acc: 0.9674 - val_loss: 2.8270 - val_cat_output_loss: 2.7645 - val_num_output_loss: 0.0625 - val_cat_output_acc: 0.1490 - val_num_output_acc: 0.9629
# Epoch 22/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 2.4700 - cat_output_loss: 2.4061 - num_output_loss: 0.0639 - cat_output_acc: 0.2457 - num_output_acc: 0.9674 - val_loss: 2.8379 - val_cat_output_loss: 2.7744 - val_num_output_loss: 0.0635 - val_cat_output_acc: 0.1454 - val_num_output_acc: 0.9629
# Epoch 23/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.4533 - cat_output_loss: 2.3895 - num_output_loss: 0.0638 - cat_output_acc: 0.2463 - num_output_acc: 0.9676 - val_loss: 2.8501 - val_cat_output_loss: 2.7873 - val_num_output_loss: 0.0628 - val_cat_output_acc: 0.1508 - val_num_output_acc: 0.9629
# Epoch 24/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.4359 - cat_output_loss: 2.3726 - num_output_loss: 0.0634 - cat_output_acc: 0.2560 - num_output_acc: 0.9674 - val_loss: 2.8628 - val_cat_output_loss: 2.8011 - val_num_output_loss: 0.0618 - val_cat_output_acc: 0.1500 - val_num_output_acc: 0.9629
# Epoch 25/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.4140 - cat_output_loss: 2.3503 - num_output_loss: 0.0637 - cat_output_acc: 0.2618 - num_output_acc: 0.9672 - val_loss: 2.8840 - val_cat_output_loss: 2.8214 - val_num_output_loss: 0.0626 - val_cat_output_acc: 0.1484 - val_num_output_acc: 0.9629
# Epoch 26/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.3934 - cat_output_loss: 2.3298 - num_output_loss: 0.0635 - cat_output_acc: 0.2652 - num_output_acc: 0.9671 - val_loss: 2.8777 - val_cat_output_loss: 2.8164 - val_num_output_loss: 0.0613 - val_cat_output_acc: 0.1460 - val_num_output_acc: 0.9629
# Epoch 27/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.3735 - cat_output_loss: 2.3103 - num_output_loss: 0.0632 - cat_output_acc: 0.2779 - num_output_acc: 0.9673 - val_loss: 2.8921 - val_cat_output_loss: 2.8308 - val_num_output_loss: 0.0613 - val_cat_output_acc: 0.1482 - val_num_output_acc: 0.9629
# Epoch 28/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.3535 - cat_output_loss: 2.2906 - num_output_loss: 0.0629 - cat_output_acc: 0.2830 - num_output_acc: 0.9670 - val_loss: 2.9348 - val_cat_output_loss: 2.8724 - val_num_output_loss: 0.0624 - val_cat_output_acc: 0.1458 - val_num_output_acc: 0.9629
# Epoch 29/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.3282 - cat_output_loss: 2.2660 - num_output_loss: 0.0622 - cat_output_acc: 0.2849 - num_output_acc: 0.9674 - val_loss: 2.9519 - val_cat_output_loss: 2.8899 - val_num_output_loss: 0.0620 - val_cat_output_acc: 0.1466 - val_num_output_acc: 0.9629
# Epoch 30/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 2.3113 - cat_output_loss: 2.2502 - num_output_loss: 0.0611 - cat_output_acc: 0.2892 - num_output_acc: 0.9671 - val_loss: 2.9337 - val_cat_output_loss: 2.8729 - val_num_output_loss: 0.0609 - val_cat_output_acc: 0.1470 - val_num_output_acc: 0.9629
# [['주간' '수' 1.0292147 1.0292147 0.0 0.0 0.0 '인천' '남동구' '차대차' '측면충돌'
#   '중앙선 침범' '단일로' '기타단일로' '자전거' '화물차']
#  ['야간' '월' 1.0539714 4.0539714 1.0 2.0 0.0 '전북' '완주군' '차대차' '기타'
#   '안전운전 의무 불이행' '단일로' '기타단일로' '승용차' '화물차']]
#
# 10 ['중상자수', '경상자수', '발생지시군구'] [32, 34]
# Train on 20029 samples, validate on 5008 samples
# Epoch 1/50
# 20029/20029 [==============================] - 1s 62us/step - loss: 5.5304 - cat_output_loss: 4.9559 - num_output_loss: 0.5745 - cat_output_acc: 0.0305 - num_output_acc: 0.5361 - val_loss: 4.5922 - val_cat_output_loss: 4.0517 - val_num_output_loss: 0.5406 - val_cat_output_acc: 0.1020 - val_num_output_acc: 0.6605
# Epoch 2/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.8253 - cat_output_loss: 3.3159 - num_output_loss: 0.5095 - cat_output_acc: 0.1153 - num_output_acc: 0.6315 - val_loss: 3.3175 - val_cat_output_loss: 2.8547 - val_num_output_loss: 0.4628 - val_cat_output_acc: 0.1396 - val_num_output_acc: 0.7919
# Epoch 3/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.4117 - cat_output_loss: 2.8969 - num_output_loss: 0.5149 - cat_output_acc: 0.1331 - num_output_acc: 0.7150 - val_loss: 3.2879 - val_cat_output_loss: 2.7954 - val_num_output_loss: 0.4926 - val_cat_output_acc: 0.1308 - val_num_output_acc: 0.9091
# Epoch 4/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.3571 - cat_output_loss: 2.8182 - num_output_loss: 0.5389 - cat_output_acc: 0.1414 - num_output_acc: 0.7318 - val_loss: 3.2222 - val_cat_output_loss: 2.7556 - val_num_output_loss: 0.4666 - val_cat_output_acc: 0.1486 - val_num_output_acc: 0.8341
# Epoch 5/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.3129 - cat_output_loss: 2.7838 - num_output_loss: 0.5291 - cat_output_acc: 0.1459 - num_output_acc: 0.7625 - val_loss: 3.1939 - val_cat_output_loss: 2.7358 - val_num_output_loss: 0.4581 - val_cat_output_acc: 0.1506 - val_num_output_acc: 0.8906
# Epoch 6/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.3966 - cat_output_loss: 2.7631 - num_output_loss: 0.6334 - cat_output_acc: 0.1482 - num_output_acc: 0.8023 - val_loss: 3.1761 - val_cat_output_loss: 2.7321 - val_num_output_loss: 0.4440 - val_cat_output_acc: 0.1496 - val_num_output_acc: 0.8758
# Epoch 7/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.2537 - cat_output_loss: 2.7301 - num_output_loss: 0.5236 - cat_output_acc: 0.1560 - num_output_acc: 0.7369 - val_loss: 3.1844 - val_cat_output_loss: 2.7107 - val_num_output_loss: 0.4737 - val_cat_output_acc: 0.1585 - val_num_output_acc: 0.8604
# Epoch 8/50
# 20029/20029 [==============================] - 1s 47us/step - loss: 3.2540 - cat_output_loss: 2.7108 - num_output_loss: 0.5432 - cat_output_acc: 0.1582 - num_output_acc: 0.7641 - val_loss: 3.1438 - val_cat_output_loss: 2.7082 - val_num_output_loss: 0.4356 - val_cat_output_acc: 0.1524 - val_num_output_acc: 0.7975
# Epoch 9/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.2204 - cat_output_loss: 2.6955 - num_output_loss: 0.5249 - cat_output_acc: 0.1615 - num_output_acc: 0.7371 - val_loss: 3.1186 - val_cat_output_loss: 2.7006 - val_num_output_loss: 0.4181 - val_cat_output_acc: 0.1591 - val_num_output_acc: 0.9062
# Epoch 10/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.1834 - cat_output_loss: 2.6859 - num_output_loss: 0.4975 - cat_output_acc: 0.1642 - num_output_acc: 0.7193 - val_loss: 3.1691 - val_cat_output_loss: 2.6941 - val_num_output_loss: 0.4750 - val_cat_output_acc: 0.1595 - val_num_output_acc: 0.9038
# Epoch 11/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.1708 - cat_output_loss: 2.6746 - num_output_loss: 0.4962 - cat_output_acc: 0.1684 - num_output_acc: 0.6972 - val_loss: 3.4809 - val_cat_output_loss: 2.7233 - val_num_output_loss: 0.7576 - val_cat_output_acc: 0.1536 - val_num_output_acc: 0.3712
# Epoch 12/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.3040 - cat_output_loss: 2.6769 - num_output_loss: 0.6270 - cat_output_acc: 0.1669 - num_output_acc: 0.7361 - val_loss: 3.1657 - val_cat_output_loss: 2.6937 - val_num_output_loss: 0.4720 - val_cat_output_acc: 0.1567 - val_num_output_acc: 0.9050
# Epoch 13/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.1995 - cat_output_loss: 2.6644 - num_output_loss: 0.5352 - cat_output_acc: 0.1686 - num_output_acc: 0.7295 - val_loss: 3.1778 - val_cat_output_loss: 2.6986 - val_num_output_loss: 0.4791 - val_cat_output_acc: 0.1595 - val_num_output_acc: 0.6633
# Epoch 14/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.1988 - cat_output_loss: 2.6559 - num_output_loss: 0.5429 - cat_output_acc: 0.1675 - num_output_acc: 0.6743 - val_loss: 3.1500 - val_cat_output_loss: 2.6965 - val_num_output_loss: 0.4535 - val_cat_output_acc: 0.1659 - val_num_output_acc: 0.8690
# Epoch 15/50
# 20029/20029 [==============================] - 1s 47us/step - loss: 3.1656 - cat_output_loss: 2.6455 - num_output_loss: 0.5201 - cat_output_acc: 0.1727 - num_output_acc: 0.7240 - val_loss: 3.1439 - val_cat_output_loss: 2.6971 - val_num_output_loss: 0.4467 - val_cat_output_acc: 0.1563 - val_num_output_acc: 0.8784
# Epoch 16/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.2050 - cat_output_loss: 2.6438 - num_output_loss: 0.5612 - cat_output_acc: 0.1748 - num_output_acc: 0.7261 - val_loss: 3.1758 - val_cat_output_loss: 2.7044 - val_num_output_loss: 0.4714 - val_cat_output_acc: 0.1490 - val_num_output_acc: 0.9065
# Epoch 17/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 3.1276 - cat_output_loss: 2.6299 - num_output_loss: 0.4978 - cat_output_acc: 0.1752 - num_output_acc: 0.6871 - val_loss: 3.1014 - val_cat_output_loss: 2.7028 - val_num_output_loss: 0.3986 - val_cat_output_acc: 0.1669 - val_num_output_acc: 0.8431
# Epoch 18/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 3.1698 - cat_output_loss: 2.6249 - num_output_loss: 0.5449 - cat_output_acc: 0.1808 - num_output_acc: 0.7093 - val_loss: 3.2330 - val_cat_output_loss: 2.7043 - val_num_output_loss: 0.5287 - val_cat_output_acc: 0.1595 - val_num_output_acc: 0.1835
# Epoch 19/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 3.1572 - cat_output_loss: 2.6233 - num_output_loss: 0.5340 - cat_output_acc: 0.1802 - num_output_acc: 0.6769 - val_loss: 3.1695 - val_cat_output_loss: 2.7106 - val_num_output_loss: 0.4589 - val_cat_output_acc: 0.1585 - val_num_output_acc: 0.8337
# Epoch 20/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.0733 - cat_output_loss: 2.6034 - num_output_loss: 0.4699 - cat_output_acc: 0.1884 - num_output_acc: 0.6705 - val_loss: 3.1523 - val_cat_output_loss: 2.6904 - val_num_output_loss: 0.4619 - val_cat_output_acc: 0.1615 - val_num_output_acc: 0.8810
# Epoch 21/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.0914 - cat_output_loss: 2.6002 - num_output_loss: 0.4912 - cat_output_acc: 0.1850 - num_output_acc: 0.6582 - val_loss: 3.1651 - val_cat_output_loss: 2.6925 - val_num_output_loss: 0.4725 - val_cat_output_acc: 0.1603 - val_num_output_acc: 0.3900
# Epoch 22/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.0819 - cat_output_loss: 2.5964 - num_output_loss: 0.4855 - cat_output_acc: 0.1881 - num_output_acc: 0.5732 - val_loss: 3.1270 - val_cat_output_loss: 2.7105 - val_num_output_loss: 0.4164 - val_cat_output_acc: 0.1563 - val_num_output_acc: 0.1649
# Epoch 23/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 3.1315 - cat_output_loss: 2.5792 - num_output_loss: 0.5523 - cat_output_acc: 0.1896 - num_output_acc: 0.6055 - val_loss: 3.2465 - val_cat_output_loss: 2.7213 - val_num_output_loss: 0.5252 - val_cat_output_acc: 0.1595 - val_num_output_acc: 0.5160
# Epoch 24/50
# 20029/20029 [==============================] - 1s 47us/step - loss: 3.0272 - cat_output_loss: 2.5804 - num_output_loss: 0.4468 - cat_output_acc: 0.1931 - num_output_acc: 0.5321 - val_loss: 3.2048 - val_cat_output_loss: 2.7088 - val_num_output_loss: 0.4960 - val_cat_output_acc: 0.1617 - val_num_output_acc: 0.3802
# Epoch 25/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.0775 - cat_output_loss: 2.5702 - num_output_loss: 0.5073 - cat_output_acc: 0.1966 - num_output_acc: 0.5965 - val_loss: 3.1778 - val_cat_output_loss: 2.7101 - val_num_output_loss: 0.4677 - val_cat_output_acc: 0.1587 - val_num_output_acc: 0.5196
# Epoch 26/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 2.9836 - cat_output_loss: 2.5603 - num_output_loss: 0.4232 - cat_output_acc: 0.1936 - num_output_acc: 0.5358 - val_loss: 3.1882 - val_cat_output_loss: 2.7193 - val_num_output_loss: 0.4689 - val_cat_output_acc: 0.1532 - val_num_output_acc: 0.2392
# Epoch 27/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.0290 - cat_output_loss: 2.5598 - num_output_loss: 0.4692 - cat_output_acc: 0.1960 - num_output_acc: 0.6061 - val_loss: 3.1452 - val_cat_output_loss: 2.7184 - val_num_output_loss: 0.4268 - val_cat_output_acc: 0.1581 - val_num_output_acc: 0.8650
# Epoch 28/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 2.9842 - cat_output_loss: 2.5473 - num_output_loss: 0.4368 - cat_output_acc: 0.2005 - num_output_acc: 0.5652 - val_loss: 3.2171 - val_cat_output_loss: 2.7058 - val_num_output_loss: 0.5113 - val_cat_output_acc: 0.1536 - val_num_output_acc: 0.2188
# Epoch 29/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 3.0139 - cat_output_loss: 2.5410 - num_output_loss: 0.4728 - cat_output_acc: 0.2027 - num_output_acc: 0.5725 - val_loss: 3.1181 - val_cat_output_loss: 2.7155 - val_num_output_loss: 0.4025 - val_cat_output_acc: 0.1593 - val_num_output_acc: 0.1631
# Epoch 30/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 2.9975 - cat_output_loss: 2.5313 - num_output_loss: 0.4662 - cat_output_acc: 0.2079 - num_output_acc: 0.5867 - val_loss: 3.1702 - val_cat_output_loss: 2.7348 - val_num_output_loss: 0.4354 - val_cat_output_acc: 0.1589 - val_num_output_acc: 0.7780
# Epoch 31/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 2.9190 - cat_output_loss: 2.5259 - num_output_loss: 0.3931 - cat_output_acc: 0.2089 - num_output_acc: 0.5172 - val_loss: 3.1699 - val_cat_output_loss: 2.7388 - val_num_output_loss: 0.4311 - val_cat_output_acc: 0.1569 - val_num_output_acc: 0.8261
# Epoch 32/50
# 20029/20029 [==============================] - 1s 47us/step - loss: 3.0692 - cat_output_loss: 2.5194 - num_output_loss: 0.5498 - cat_output_acc: 0.2104 - num_output_acc: 0.6019 - val_loss: 3.1454 - val_cat_output_loss: 2.7357 - val_num_output_loss: 0.4097 - val_cat_output_acc: 0.1599 - val_num_output_acc: 0.6118
# Epoch 33/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 2.9553 - cat_output_loss: 2.5024 - num_output_loss: 0.4529 - cat_output_acc: 0.2147 - num_output_acc: 0.5584 - val_loss: 3.1738 - val_cat_output_loss: 2.7252 - val_num_output_loss: 0.4485 - val_cat_output_acc: 0.1540 - val_num_output_acc: 0.1442
# Epoch 34/50
# 20029/20029 [==============================] - 1s 49us/step - loss: 3.1981 - cat_output_loss: 2.5071 - num_output_loss: 0.6910 - cat_output_acc: 0.2104 - num_output_acc: 0.5524 - val_loss: 3.1587 - val_cat_output_loss: 2.7371 - val_num_output_loss: 0.4216 - val_cat_output_acc: 0.1522 - val_num_output_acc: 0.8954
# Epoch 35/50
# 20029/20029 [==============================] - 1s 48us/step - loss: 2.8686 - cat_output_loss: 2.4922 - num_output_loss: 0.3764 - cat_output_acc: 0.2181 - num_output_acc: 0.5647 - val_loss: 3.1936 - val_cat_output_loss: 2.7393 - val_num_output_loss: 0.4543 - val_cat_output_acc: 0.1526 - val_num_output_acc: 0.9054
# Epoch 36/50
# 20029/20029 [==============================] - 1s 47us/step - loss: 3.0243 - cat_output_loss: 2.4939 - num_output_loss: 0.5304 - cat_output_acc: 0.2199 - num_output_acc: 0.5966 - val_loss: 3.1719 - val_cat_output_loss: 2.7415 - val_num_output_loss: 0.4304 - val_cat_output_acc: 0.1542 - val_num_output_acc: 0.1723
# Epoch 37/50
# 20029/20029 [==============================] - 1s 47us/step - loss: 2.9462 - cat_output_loss: 2.4798 - num_output_loss: 0.4664 - cat_output_acc: 0.2243 - num_output_acc: 0.6065 - val_loss: 3.2007 - val_cat_output_loss: 2.7446 - val_num_output_loss: 0.4561 - val_cat_output_acc: 0.1540 - val_num_output_acc: 0.9024
# [['야간' '일' 1.0 2.0 '0.48831254' '0.34055817' 0.0 '대구' '달성군' '차대차' '측면충돌'
#   '안전운전 의무 불이행' '단일로' '기타단일로' '승용차' '승용차']
#  ['주간' '일' 1.0 6.0 '1.098893' '3.3756592' 0.0 '광주' '북구' '차대차' '추돌'
# ...
# Epoch 11/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.2833 - cat_output_loss: 0.2309 - num_output_loss: 0.0524 - cat_output_acc: 0.8934 - num_output_acc: 0.9669 - val_loss: 0.3307 - val_cat_output_loss: 0.2473 - val_num_output_loss: 0.0834 - val_cat_output_acc: 0.8831 - val_num_output_acc: 0.9595
# Epoch 12/50
# 20029/20029 [==============================] - 1s 51us/step - loss: 0.2823 - cat_output_loss: 0.2294 - num_output_loss: 0.0529 - cat_output_acc: 0.8945 - num_output_acc: 0.9661 - val_loss: 0.3158 - val_cat_output_loss: 0.2480 - val_num_output_loss: 0.0678 - val_cat_output_acc: 0.8820 - val_num_output_acc: 0.9585
# Epoch 13/50
# 20029/20029 [==============================] - 1s 51us/step - loss: 0.2761 - cat_output_loss: 0.2267 - num_output_loss: 0.0494 - cat_output_acc: 0.8963 - num_output_acc: 0.9688 - val_loss: 0.3262 - val_cat_output_loss: 0.2485 - val_num_output_loss: 0.0777 - val_cat_output_acc: 0.8814 - val_num_output_acc: 0.9591
# Epoch 14/50
# 20029/20029 [==============================] - 1s 51us/step - loss: 0.2707 - cat_output_loss: 0.2236 - num_output_loss: 0.0471 - cat_output_acc: 0.8986 - num_output_acc: 0.9694 - val_loss: 0.3150 - val_cat_output_loss: 0.2511 - val_num_output_loss: 0.0639 - val_cat_output_acc: 0.8820 - val_num_output_acc: 0.9601
# Epoch 15/50
# 20029/20029 [==============================] - 1s 47us/step - loss: 0.2683 - cat_output_loss: 0.2211 - num_output_loss: 0.0473 - cat_output_acc: 0.9000 - num_output_acc: 0.9682 - val_loss: 0.3228 - val_cat_output_loss: 0.2492 - val_num_output_loss: 0.0736 - val_cat_output_acc: 0.8801 - val_num_output_acc: 0.9505
# Epoch 16/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.2610 - cat_output_loss: 0.2182 - num_output_loss: 0.0428 - cat_output_acc: 0.9020 - num_output_acc: 0.9688 - val_loss: 0.3155 - val_cat_output_loss: 0.2519 - val_num_output_loss: 0.0636 - val_cat_output_acc: 0.8811 - val_num_output_acc: 0.9585
# Epoch 17/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.2564 - cat_output_loss: 0.2161 - num_output_loss: 0.0403 - cat_output_acc: 0.9032 - num_output_acc: 0.9711 - val_loss: 0.3218 - val_cat_output_loss: 0.2526 - val_num_output_loss: 0.0691 - val_cat_output_acc: 0.8800 - val_num_output_acc: 0.9605
# Epoch 18/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.2528 - cat_output_loss: 0.2124 - num_output_loss: 0.0404 - cat_output_acc: 0.9053 - num_output_acc: 0.9697 - val_loss: 0.3246 - val_cat_output_loss: 0.2571 - val_num_output_loss: 0.0675 - val_cat_output_acc: 0.8789 - val_num_output_acc: 0.9595
# Epoch 19/50
# 20029/20029 [==============================] - 1s 48us/step - loss: 0.2476 - cat_output_loss: 0.2102 - num_output_loss: 0.0374 - cat_output_acc: 0.9060 - num_output_acc: 0.9712 - val_loss: 0.3230 - val_cat_output_loss: 0.2537 - val_num_output_loss: 0.0692 - val_cat_output_acc: 0.8789 - val_num_output_acc: 0.9607
# Epoch 20/50
# 20029/20029 [==============================] - 1s 48us/step - loss: 0.2458 - cat_output_loss: 0.2073 - num_output_loss: 0.0385 - cat_output_acc: 0.9083 - num_output_acc: 0.9721 - val_loss: 0.3229 - val_cat_output_loss: 0.2587 - val_num_output_loss: 0.0642 - val_cat_output_acc: 0.8780 - val_num_output_acc: 0.9601
# Epoch 21/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.2398 - cat_output_loss: 0.2050 - num_output_loss: 0.0347 - cat_output_acc: 0.9099 - num_output_acc: 0.9714 - val_loss: 0.3367 - val_cat_output_loss: 0.2607 - val_num_output_loss: 0.0760 - val_cat_output_acc: 0.8792 - val_num_output_acc: 0.9539
# Epoch 22/50
# 20029/20029 [==============================] - 1s 49us/step - loss: 0.2383 - cat_output_loss: 0.2016 - num_output_loss: 0.0368 - cat_output_acc: 0.9118 - num_output_acc: 0.9727 - val_loss: 0.3321 - val_cat_output_loss: 0.2642 - val_num_output_loss: 0.0678 - val_cat_output_acc: 0.8778 - val_num_output_acc: 0.9585
# Epoch 23/50
# 20029/20029 [==============================] - 1s 49us/step - loss: 0.2310 - cat_output_loss: 0.1985 - num_output_loss: 0.0324 - cat_output_acc: 0.9131 - num_output_acc: 0.9743 - val_loss: 0.3340 - val_cat_output_loss: 0.2688 - val_num_output_loss: 0.0652 - val_cat_output_acc: 0.8775 - val_num_output_acc: 0.9593
# Epoch 24/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.2333 - cat_output_loss: 0.1958 - num_output_loss: 0.0375 - cat_output_acc: 0.9148 - num_output_acc: 0.9730 - val_loss: 0.3386 - val_cat_output_loss: 0.2671 - val_num_output_loss: 0.0715 - val_cat_output_acc: 0.8769 - val_num_output_acc: 0.9581
# Epoch 25/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.2274 - cat_output_loss: 0.1934 - num_output_loss: 0.0340 - cat_output_acc: 0.9165 - num_output_acc: 0.9728 - val_loss: 0.3356 - val_cat_output_loss: 0.2683 - val_num_output_loss: 0.0673 - val_cat_output_acc: 0.8769 - val_num_output_acc: 0.9595
# Epoch 26/50
# 20029/20029 [==============================] - 1s 48us/step - loss: 0.2335 - cat_output_loss: 0.1925 - num_output_loss: 0.0410 - cat_output_acc: 0.9169 - num_output_acc: 0.9733 - val_loss: 0.3340 - val_cat_output_loss: 0.2691 - val_num_output_loss: 0.0649 - val_cat_output_acc: 0.8770 - val_num_output_acc: 0.9585
# Epoch 27/50
# 20029/20029 [==============================] - 1s 53us/step - loss: 0.2226 - cat_output_loss: 0.1880 - num_output_loss: 0.0346 - cat_output_acc: 0.9186 - num_output_acc: 0.9741 - val_loss: 0.3450 - val_cat_output_loss: 0.2759 - val_num_output_loss: 0.0691 - val_cat_output_acc: 0.8755 - val_num_output_acc: 0.9591
# Epoch 28/50
# 20029/20029 [==============================] - 1s 48us/step - loss: 0.2226 - cat_output_loss: 0.1858 - num_output_loss: 0.0369 - cat_output_acc: 0.9203 - num_output_acc: 0.9739 - val_loss: 0.3470 - val_cat_output_loss: 0.2747 - val_num_output_loss: 0.0723 - val_cat_output_acc: 0.8756 - val_num_output_acc: 0.9561
# Epoch 29/50
# 20029/20029 [==============================] - 1s 48us/step - loss: 0.2183 - cat_output_loss: 0.1838 - num_output_loss: 0.0345 - cat_output_acc: 0.9212 - num_output_acc: 0.9748 - val_loss: 0.3521 - val_cat_output_loss: 0.2857 - val_num_output_loss: 0.0664 - val_cat_output_acc: 0.8748 - val_num_output_acc: 0.9605
# [['주간' '일' 0.99279207 0.99279207 0.0 0.0 0.0 '전북' '고창군' '차대사람' '기타'
#   '부당한 회전' '교차로' '교차로내' '승용차' '보행자']
#  ['야간' '일' 0.9573215 2.9573215 1.0 1.0 0.0 '서울' '은평구' '차대차' '기타' '신호위반'
#   '교차로' '교차로내' '승용차' '승용차']]
#
# 15 ['사상자수', '중상자수', '주야', '도로형태'] [47, 49]
# Train on 20029 samples, validate on 5008 samples
# Epoch 1/50
# 20029/20029 [==============================] - 1s 64us/step - loss: 1.2293 - cat_output_loss: 0.2398 - num_output_loss: 0.9895 - cat_output_acc: 0.8966 - num_output_acc: 0.7601 - val_loss: 1.3093 - val_cat_output_loss: 0.1885 - val_num_output_loss: 1.1208 - val_cat_output_acc: 0.9075 - val_num_output_acc: 0.8193
# Epoch 2/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 1.0871 - cat_output_loss: 0.1570 - num_output_loss: 0.9301 - cat_output_acc: 0.9205 - num_output_acc: 0.8051 - val_loss: 1.0448 - val_cat_output_loss: 0.1468 - val_num_output_loss: 0.8980 - val_cat_output_acc: 0.9245 - val_num_output_acc: 0.7909
# Epoch 3/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 1.0061 - cat_output_loss: 0.1402 - num_output_loss: 0.8659 - cat_output_acc: 0.9254 - num_output_acc: 0.8076 - val_loss: 1.3058 - val_cat_output_loss: 0.1377 - val_num_output_loss: 1.1682 - val_cat_output_acc: 0.9258 - val_num_output_acc: 0.7891
# Epoch 4/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 1.0243 - cat_output_loss: 0.1380 - num_output_loss: 0.8863 - cat_output_acc: 0.9269 - num_output_acc: 0.8091 - val_loss: 1.1753 - val_cat_output_loss: 0.1374 - val_num_output_loss: 1.0378 - val_cat_output_acc: 0.9281 - val_num_output_acc: 0.8197
# Epoch 5/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 0.9846 - cat_output_loss: 0.1361 - num_output_loss: 0.8485 - cat_output_acc: 0.9302 - num_output_acc: 0.8107 - val_loss: 1.1394 - val_cat_output_loss: 0.1341 - val_num_output_loss: 1.0053 - val_cat_output_acc: 0.9335 - val_num_output_acc: 0.7987
# Epoch 6/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 0.8234 - cat_output_loss: 0.1336 - num_output_loss: 0.6898 - cat_output_acc: 0.9322 - num_output_acc: 0.8156 - val_loss: 1.4345 - val_cat_output_loss: 0.1321 - val_num_output_loss: 1.3024 - val_cat_output_acc: 0.9351 - val_num_output_acc: 0.8027
# Epoch 7/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 0.8449 - cat_output_loss: 0.1312 - num_output_loss: 0.7137 - cat_output_acc: 0.9336 - num_output_acc: 0.8154 - val_loss: 1.0216 - val_cat_output_loss: 0.1286 - val_num_output_loss: 0.8929 - val_cat_output_acc: 0.9374 - val_num_output_acc: 0.8147
# Epoch 8/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 0.8778 - cat_output_loss: 0.1313 - num_output_loss: 0.7465 - cat_output_acc: 0.9339 - num_output_acc: 0.8150 - val_loss: 0.9842 - val_cat_output_loss: 0.1278 - val_num_output_loss: 0.8564 - val_cat_output_acc: 0.9356 - val_num_output_acc: 0.7672
# Epoch 9/50
# 20029/20029 [==============================] - 1s 48us/step - loss: 0.8343 - cat_output_loss: 0.1294 - num_output_loss: 0.7049 - cat_output_acc: 0.9344 - num_output_acc: 0.8188 - val_loss: 1.1013 - val_cat_output_loss: 0.1258 - val_num_output_loss: 0.9755 - val_cat_output_acc: 0.9367 - val_num_output_acc: 0.7915
# Epoch 10/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 0.7674 - cat_output_loss: 0.1304 - num_output_loss: 0.6370 - cat_output_acc: 0.9347 - num_output_acc: 0.8194 - val_loss: 1.0687 - val_cat_output_loss: 0.1287 - val_num_output_loss: 0.9400 - val_cat_output_acc: 0.9372 - val_num_output_acc: 0.8131
# Epoch 11/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.7094 - cat_output_loss: 0.1279 - num_output_loss: 0.5814 - cat_output_acc: 0.9359 - num_output_acc: 0.8269 - val_loss: 1.1200 - val_cat_output_loss: 0.1246 - val_num_output_loss: 0.9954 - val_cat_output_acc: 0.9372 - val_num_output_acc: 0.7831
# Epoch 12/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.7215 - cat_output_loss: 0.1251 - num_output_loss: 0.5964 - cat_output_acc: 0.9369 - num_output_acc: 0.8291 - val_loss: 1.0679 - val_cat_output_loss: 0.1227 - val_num_output_loss: 0.9452 - val_cat_output_acc: 0.9390 - val_num_output_acc: 0.8071
# Epoch 13/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 0.6604 - cat_output_loss: 0.1242 - num_output_loss: 0.5361 - cat_output_acc: 0.9373 - num_output_acc: 0.8291 - val_loss: 1.1436 - val_cat_output_loss: 0.1221 - val_num_output_loss: 1.0215 - val_cat_output_acc: 0.9387 - val_num_output_acc: 0.7965
# Epoch 14/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 0.6116 - cat_output_loss: 0.1223 - num_output_loss: 0.4893 - cat_output_acc: 0.9381 - num_output_acc: 0.8357 - val_loss: 1.2553 - val_cat_output_loss: 0.1211 - val_num_output_loss: 1.1342 - val_cat_output_acc: 0.9391 - val_num_output_acc: 0.8089
# Epoch 15/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 0.7172 - cat_output_loss: 0.1220 - num_output_loss: 0.5952 - cat_output_acc: 0.9377 - num_output_acc: 0.8311 - val_loss: 1.1057 - val_cat_output_loss: 0.1210 - val_num_output_loss: 0.9847 - val_cat_output_acc: 0.9391 - val_num_output_acc: 0.8045
# Epoch 16/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 0.5444 - cat_output_loss: 0.1215 - num_output_loss: 0.4229 - cat_output_acc: 0.9376 - num_output_acc: 0.8342 - val_loss: 1.1120 - val_cat_output_loss: 0.1200 - val_num_output_loss: 0.9921 - val_cat_output_acc: 0.9405 - val_num_output_acc: 0.7981
# Epoch 17/50
# 20029/20029 [==============================] - 1s 48us/step - loss: 0.6320 - cat_output_loss: 0.1207 - num_output_loss: 0.5112 - cat_output_acc: 0.9385 - num_output_acc: 0.8369 - val_loss: 1.0753 - val_cat_output_loss: 0.1204 - val_num_output_loss: 0.9549 - val_cat_output_acc: 0.9401 - val_num_output_acc: 0.7963
# Epoch 18/50
# 20029/20029 [==============================] - 1s 46us/step - loss: 0.5716 - cat_output_loss: 0.1207 - num_output_loss: 0.4508 - cat_output_acc: 0.9392 - num_output_acc: 0.8363 - val_loss: 1.0636 - val_cat_output_loss: 0.1199 - val_num_output_loss: 0.9437 - val_cat_output_acc: 0.9409 - val_num_output_acc: 0.8021
# Epoch 19/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.8137 - cat_output_loss: 0.1208 - num_output_loss: 0.6929 - cat_output_acc: 0.9385 - num_output_acc: 0.8382 - val_loss: 1.0283 - val_cat_output_loss: 0.1211 - val_num_output_loss: 0.9073 - val_cat_output_acc: 0.9398 - val_num_output_acc: 0.7750
# Epoch 20/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.6638 - cat_output_loss: 0.1207 - num_output_loss: 0.5432 - cat_output_acc: 0.9386 - num_output_acc: 0.8429 - val_loss: 1.1084 - val_cat_output_loss: 0.1205 - val_num_output_loss: 0.9879 - val_cat_output_acc: 0.9398 - val_num_output_acc: 0.8039
# Epoch 21/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.6366 - cat_output_loss: 0.1203 - num_output_loss: 0.5163 - cat_output_acc: 0.9387 - num_output_acc: 0.8398 - val_loss: 1.1976 - val_cat_output_loss: 0.1204 - val_num_output_loss: 1.0772 - val_cat_output_acc: 0.9403 - val_num_output_acc: 0.8131
# Epoch 22/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.5544 - cat_output_loss: 0.1196 - num_output_loss: 0.4348 - cat_output_acc: 0.9393 - num_output_acc: 0.8426 - val_loss: 1.2813 - val_cat_output_loss: 0.1191 - val_num_output_loss: 1.1622 - val_cat_output_acc: 0.9400 - val_num_output_acc: 0.8055
# Epoch 23/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.8042 - cat_output_loss: 0.1200 - num_output_loss: 0.6841 - cat_output_acc: 0.9393 - num_output_acc: 0.8437 - val_loss: 1.0317 - val_cat_output_loss: 0.1202 - val_num_output_loss: 0.9115 - val_cat_output_acc: 0.9404 - val_num_output_acc: 0.7953
# Epoch 24/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.6430 - cat_output_loss: 0.1196 - num_output_loss: 0.5234 - cat_output_acc: 0.9395 - num_output_acc: 0.8463 - val_loss: 1.1283 - val_cat_output_loss: 0.1188 - val_num_output_loss: 1.0095 - val_cat_output_acc: 0.9414 - val_num_output_acc: 0.8099
# Epoch 25/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.5070 - cat_output_loss: 0.1192 - num_output_loss: 0.3878 - cat_output_acc: 0.9396 - num_output_acc: 0.8487 - val_loss: 1.0914 - val_cat_output_loss: 0.1188 - val_num_output_loss: 0.9725 - val_cat_output_acc: 0.9412 - val_num_output_acc: 0.8051
# Epoch 26/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.4602 - cat_output_loss: 0.1188 - num_output_loss: 0.3413 - cat_output_acc: 0.9395 - num_output_acc: 0.8518 - val_loss: 1.0825 - val_cat_output_loss: 0.1197 - val_num_output_loss: 0.9628 - val_cat_output_acc: 0.9409 - val_num_output_acc: 0.8013
# Epoch 27/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.4450 - cat_output_loss: 0.1186 - num_output_loss: 0.3264 - cat_output_acc: 0.9398 - num_output_acc: 0.8475 - val_loss: 1.0072 - val_cat_output_loss: 0.1192 - val_num_output_loss: 0.8880 - val_cat_output_acc: 0.9402 - val_num_output_acc: 0.7969
# Epoch 28/50
# 20029/20029 [==============================] - 1s 45us/step - loss: 0.4801 - cat_output_loss: 0.1184 - num_output_loss: 0.3617 - cat_output_acc: 0.9399 - num_output_acc: 0.8519 - val_loss: 1.1206 - val_cat_output_loss: 0.1185 - val_num_output_loss: 1.0020 - val_cat_output_acc: 0.9410 - val_num_output_acc: 0.8025
# [['주간' '목' 1.0 1.09048228 0.09048228 0.0 0.0 '서울' '성동구' '차대차' '측면충돌'
#   '안전운전 의무 불이행' '교차로' '교차로내' '자전거' '승용차']
#  ['주간' '일' 2.0 17.1848507 5.1848507 9.0 1.0 '서울' '서초구' '차대차' '추돌'
#   '안전운전 의무 불이행' '단일로' '기타단일로' '승합차' '승용차']
#  ['주간' '화' 1.0 1.070507884 0.070507884 0.0 0.0 '경북' '의성군' '차대차' '측면충돌'
#   '안전운전 의무 불이행' '교차로' '교차로내' '승용차' '원동기장치자전거']]

# %%
test_arr
# Out:
# array([['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도',
#         '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태',
#         '당사자종별_1당_대분류', '당사자종별_2당_대분류'],
#        ['야간', '금', 1.0739396, 1.7806155681610107, 0.0, 0.706676, 0.0,
#         '경기', '화성시', '차대차', '측면충돌', '중앙선 침범', '단일로', '기타단일로', '승용차',
#         '승합차'],
#        ['야간', '금', 0.9898085, 1.0485250875353813, 0.0, 0.058716588, 0.0,
#         '전남', '영암군', '차대사람', '차도통행중', '과속', '단일로', '기타단일로', '승용차', '보행자'],
#        ['야간', '월', 1.0, 1.0424908297136426, 0.038185462, 0.0,
#         0.0043053674, '전남', '곡성군', '차량단독', '전도전복', '안전운전 의무 불이행', '단일로',
#         '기타단일로', '자전거', '없음'],
#        ['야간', '일', 2.0, 3.843921422958374, 0.7947301, 1.0, 0.049191296,
#         '대구', '달성군', '차대차', '측면충돌', '중앙선 침범', '단일로', '기타단일로', '승용차',
#         '승합차'],
#        ['주간', '목', 1.0, 2.583216428756714, 1.0845929, 0.4986235, 0.0,
#         '전남', '고흥군', '차대차', '정면충돌', '중앙선 침범', '단일로', '기타단일로', '화물차',
#         '화물차'],
#        ['주간', '목', 2.0, 3.3249988555908203, 0.94152194, 0.3834769, 0.0,
#         '경북', '영천시', '차대차', '추돌', '안전운전 의무 불이행', '단일로', '기타단일로', '화물차',
#         '화물차'],
#        ['야간', '수', 1.0, 1.6880871653556824, 0.36311215, 0.324975, 0.0,
#         '충남', '아산시', '차대차', '추돌', '안전거리 미확보', '단일로', '기타단일로', '승합차',
#         '화물차'],
#        ['주간', '월', 1.0746013, 6.599655568599701, 0.5250543, 5.0, 0.0,
#         '충남', '서천군', '차대차', '추돌', '안전운전 의무 불이행', '단일로', '기타단일로', '승용차',
#         '특수차'],
#        ['주간', '일', 2.0433056, 38.72815251350403, 11.684847, 21.0, 4.0,
#         '강원', '평창군', '차대차', '측면충돌', '기타(운전자법규위반)', '단일로', '기타단일로',
#         '건설기계', '승합차'],
#        ['주간', '수', 1.028527, 1.0791440345346928, 0.050617013, 0.0, 0.0,
#         '충북', '음성군', '차대사람', '횡단중', '과속', '교차로', '교차로내', '승용차', '보행자'],
#        ['주간', '수', 1.0, 2.0, 1.0, 0.0, 0.0, '경남', '의령군', '차대차', '측면직각충돌',
#         '신호위반', '교차로', '교차로내', '이륜차', '화물차'],
#        ['야간', '화', 2.0, 3.0, 1.0, 0.0, 0.0, '대전', '중구', '차량단독', '전도전복',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '원동기장치자전거', '없음'],
#        ['야간', '화', 1.0, 1.0, 0.0, 0.0, 0.0, '대구', '북구', '차대차', '추돌',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '승용차', '화물차'],
#        ['야간', '화', 1.0, 1.0, 0.0, 0.0, 0.0, '울산', '울주군', '차대사람', '기타',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '승용차', '보행자'],
#        ['주간', '화', 1.0, 5.0, 1.0, 3.0, 0.0, '경기', '수원시', '차대차', '측면직각충돌',
#         '중앙선 침범', '단일로', '교량위', '화물차', '승용차'],
#        ['주간', '화', 1.0, 1.0, 0.0, 0.0, 0.0, '전북', '완주군', '차대사람', '횡단중',
#         '안전운전 의무 불이행', '교차로', '교차로횡단보도내', '승합차', '보행자'],
#        ['주간', '화', 1.0, 6.0, 3.0, 2.0, 0.0, '경남', '거창군', '차대차', '측면직각충돌',
#         '직진 및 우회전차의 통행방해', '교차로', '교차로내', '승용차', '승합차'],
#        ['야간', '화', 1.0, 1.0, 0.0, 0.0, 0.0, '충남', '천안시', '차대사람', '횡단중',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '승용차', '보행자'],
#        ['주간', '화', 1.0, 11.0, 2.0, 8.0, 0.0, '충남', '서산시', '차대차', '추돌',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '화물차', '승용차'],
#        ['주간', '화', 1.0, 1.0, 0.0, 0.0, 0.0, '전남', '곡성군', '차대사람', '횡단중',
#         '안전운전 의무 불이행', '교차로', '교차로내', '승합차', '보행자'],
#        ['야간', '토', 1.0, 11.0, 0.0, 0.0, 10.0, '경기', '의왕시', '차대차', '추돌',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '승용차', '화물차'],
#        ['주간', '화', 1.0, 13.0, 3.0, 9.0, 0.0, '경기', '평택시', '차대차', '추돌',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '화물차', '화물차'],
#        ['주간', '화', 1.0, 1.0, 0.0, 0.0, 0.0, '전남', '광양시', '차대사람', '보도통행중',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '승용차', '보행자'],
#        ['야간', '목', 1.0, 2.0, 0.0, 1.0, 0.0, '경기', '평택시', '차대차', '측면충돌',
#         '신호위반', '교차로', '교차로내', '승용차', '승용차'],
#        ['야간', '목', 1.0, 2.0, 0.0, 1.0, 0.0, '충남', '당진시', '차량단독', '공작물충돌',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '이륜차', '없음'],
#        ['야간', '월', 1.0, 1.0, 0.0, 0.0, 0.0, '전북', '익산시', '차대사람', '기타',
#         '보행자 보호의무 위반', '단일로', '횡단보도상', '승용차', '보행자'],
#        ['야간', '월', 1.0, 2.0, 0.0, 1.0, 0.0, '경남', '하동군', '차대차', '추돌',
#         '과속', '단일로', '기타단일로', '승용차', '승용차'],
#        ['야간', '월', 1.0, 2.0, 1.0, 0.0, 0.0, '서울', '동대문구', '차대차', '측면충돌',
#         '안전운전 의무 불이행', '교차로', '교차로내', '이륜차', '승용차'],
#        ['야간', '수', 1.0, 1.0, 0.0, 0.0, 0.0, '경기', '평택시', '차량단독', '기타',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '승용차', '없음'],
#        ['주간', '수', 2.0, 5.0, 1.0, 2.0, 0.0, '충남', '홍성군', '차대차', '추돌',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '화물차', '화물차'],
#        ['주간', '수', 1.0292147, 1.0292147, 0.0, 0.0, 0.0, '인천', '남동구',
#         '차대차', '측면충돌', '중앙선 침범', '단일로', '기타단일로', '자전거', '화물차'],
#        ['야간', '월', 1.0539714, 4.0539714, 1.0, 2.0, 0.0, '전북', '완주군',
#         '차대차', '기타', '안전운전 의무 불이행', '단일로', '기타단일로', '승용차', '화물차'],
#        ['야간', '일', 1.0, 2.0, '0.48831254', '0.34055817', 0.0, '대구',
#         '달성군', '차대차', '측면충돌', '안전운전 의무 불이행', '단일로', '기타단일로', '승용차',
#         '승용차'],
#        ['주간', '일', 1.0, 6.0, '1.098893', '3.3756592', 0.0, '광주', '북구',
#         '차대차', '추돌', '안전운전 의무 불이행', '교차로', '교차로부근', '승용차', '승용차'],
#        ['주간', '수', 1.0, 4.0, '1.2954408', '0.8936435', 0.0, '서울', '송파구',
#         '차대차', '추돌', '안전운전 의무 불이행', '단일로', '기타단일로', '화물차', '화물차'],
#        ['야간', '수', 1.0, 4.0, 3.0, 0.0, 0.0, '경북', '경주시', '차대차', '정면충돌',
#         '중앙선 침범', '단일로', '기타단일로', '승용차', '화물차'],
#        ['주간', '월', 2.0, 2.0, 0.0, 0.0, 0.0, '경기', '경주시', '차량단독', '공작물충돌',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '승용차', '없음'],
#        ['주간', '월', 1.0, 1.0, 0.0, 0.0, 0.0, '경기', '중구', '차대사람', '기타',
#         '안전운전 의무 불이행', '교차로', '교차로부근', '승합차', '보행자'],
#        ['주간', '월', 1.0, 19.0, 9.0, 9.0, 0.0, '경남', '서구', '차대차', '추돌',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '승합차', '승용차'],
#        ['야간', '월', 1.0, 1.0, 0.0, 0.0, 0.0, '경기', '중구', '차대사람', '기타',
#         '안전운전 의무 불이행', '교차로', '교차로내', '승용차', '보행자'],
#        ['주간', '토', 1.0, 1.0, 0.0, 0.0, 0.0, '서울', '동작구', '차대차', '측면직각충돌',
#         '신호위반', '교차로', '교차로내', '화물차', '원동기장치자전거'],
#        ['주간', '토', 1.0, 4.0, 3.0, 0.0, 0.0, '경기', '가평군', '차대차', '기타',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '승합차', '승용차'],
#        ['주간', '수', 1.0, 1.0, 0.0, 0.0, 0.0, '경기', '부천시', '차대차', '측면직각충돌',
#         '신호위반', '교차로', '교차로내', '승합차', '이륜차'],
#        ['주간', '월', 1.0, 1.0, 0.0, 0.0, 0.0, '대전', '동구', '차량단독', '공작물충돌',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '특수차', '없음'],
#        ['야간', '토', 2.0, 2.0, 0.0, 0.0, 0.0, '충남', '보령시', '차대사람', '기타',
#         '안전운전 의무 불이행', '단일로', '기타단일로', '승용차', '보행자'],
#        ['주간', '일', 0.99279207, 0.99279207, 0.0, 0.0, 0.0, '전북', '고창군',
#         '차대사람', '기타', '부당한 회전', '교차로', '교차로내', '승용차', '보행자'],
#        ['야간', '일', 0.9573215, 2.9573215, 1.0, 1.0, 0.0, '서울', '은평구',
#         '차대차', '기타', '신호위반', '교차로', '교차로내', '승용차', '승용차'],
#        ['주간', '목', 1.0, 1.09048228, 0.09048228, 0.0, 0.0, '서울', '성동구',
#         '차대차', '측면충돌', '안전운전 의무 불이행', '교차로', '교차로내', '자전거', '승용차'],
#        ['주간', '일', 2.0, 17.1848507, 5.1848507, 9.0, 1.0, '서울', '서초구',
#         '차대차', '추돌', '안전운전 의무 불이행', '단일로', '기타단일로', '승합차', '승용차'],
#        ['주간', '화', 1.0, 1.070507884, 0.070507884, 0.0, 0.0, '경북', '의성군',
#         '차대차', '측면충돌', '안전운전 의무 불이행', '교차로', '교차로내', '승용차', '원동기장치자전거']],
#       dtype=object)

# %%
with open('./test_kor_1.csv','wb',) as f:
        np.savetxt(f,  test_arr,  delimiter=",", fmt='%s', encoding='cp949')

# %%
save_result()
# Out:
# Save Success
